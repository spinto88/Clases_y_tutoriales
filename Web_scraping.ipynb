# %% [markdown]
# <a href="https://colab.research.google.com/github/spinto88/Clases_y_tutoriales/blob/main/Web_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Trabajando con el contenido estático de una página
#
# Vamos a comenzar trabajando haciendo un simple request a una página, obteniendo así el código HTML de la misma.
#
# Al hacer un request estamos sacando un foto de la página: su contenido es completamente estático. Por estático nos referimos a que no vamos a tener habilitadas opciones como *scrollear* o bien clickear algún que otro botón. Esto último es importante porque muchas veces hay contenido que solo se puede acceder a través de dichos métodos. Trabajar con contenido dinámico lo vamos a ver aparte de esta notebook (en caso de necesitar, cuando trabajemos, por ejemplo, con la librería *selenium*).
#
# Dado que sacamos una foto de la página, recibimos un código que vamos a tener que *parsearlo*, es decir, convertirlo en un objeto manipulable en el que sea fácil navegar. Esto lo hacemos con el módulo *BeautifulSoup*.

# %%
# Importamos las librerías que vamos a utilizar
import requests
from bs4 import BeautifulSoup as BS
import time

# %% [markdown]
# Comencemos como prueba con el *homepage* del diario La Nación. Recordar que una vez que hacemos el request ya dejamos de interactuar con la página:

# %%
# Hacemos un request a la página de La Nación
response = requests.get("https://www.lanacion.com.ar")

# Vemos el contenido que nos devolvió
print(response.status_code)
print(response.content)
# Out:
# 200
# b'<!DOCTYPE html><html lang="es"><head><meta charset="utf-8"/><meta name="viewport" content="width=device-width,initial-scale=1.0,minimum-scale=0.5,maximum-scale=5.0,user-scalable=yes"/><meta name="theme-color" content="#ffffff"/><title>\xc3\x9altimas noticias de Argentina y el mundo - LA NACION</title><link rel="preload" as="image" fetchPriority="high" media="(min-width: 768px)" href="https://www.lanacion.com.ar/resizer/v2/juan-schiaretti-y-sergio-massa-en-el-segundo-Y6OVNITB3FF3XFITF3T73AGHFU.jpg?auth=8b161b934a382db1fd99319b003ea190708953cd64c6f6cd8a9e6fb8d132bf22&amp;width=488&amp;height=325&amp;quality=70&amp;smart=true"/><link rel="preload" as="image" fetchPriority="high" media="(max-width: 767px)" href="https://www.lanacion.com.ar/resizer/v2/juan-schiaretti-y-sergio-massa-en-el-segundo-Y6OVNITB3FF3XFITF3T73AGHFU.jpg?auth=8b161b934a382db1fd99319b003ea190708953cd64c6f6cd8a9e6fb8d132bf22&amp;width=420&amp;height=280&amp;quality=70&amp;smart=true"/><style>\n@font-face {font-family:\'Prumo\';src:url(\'/pf/resources/fonts/prumo/Prumo-LNVF.woff2?d=1374\') format(\'woff2-variations\'); font-weight: 90; font-display: swap;}\n@font-face {font-family:\'Prumo Italic\';src:url(\'/pf/resources/fonts/prumo/Prumo-ItalicLNVF.woff2?d=1374\') format(\'woff2-variations\'); font-weight: 90; font-display: swap;}\n.--prumo{font-family:"Prumo","Georgia"}.--font-primary{font-family:"Prumo","Georgia"}.row{display:flex;flex-wrap:wrap;width:100%}[class*=col-]{width:100%;position:relative}.col{flex-basis:0%;flex-grow:1;max-width:100%}.col-1{flex:0 0 8.3333333333%;max-width:8.3333333333%}.col-2{flex:0 0 16.6666666667%;max-width:16.6666666667%}.col-3{flex:0 0 25%;max-width:25%}.col-4{flex:0 0 33.3333333333%;max-width:33.3333333333%}.col-5{flex:0 0 41.6666666667%;max-width:41.6666666667%}.col-6{flex:0 0 50%;max-width:50%}.col-7{flex:0 0 58.3333333333%;max-width:58.3333333333%}.col-8{flex:0 0 66.6666666667%;max-width:66.6666666667%}.col-9{flex:0 0 75%;max-width:75%}.col-10{flex:0 0 83.3333333333%;max-width:83.3333333333%}.col-11{flex:0 0 91.6666666667%;max-width:91.6666666667%}.col-12{flex:0 0 100%;max-width:100%}@media (min-width:768px){.col-tablet{flex-basis:0%;flex-grow:1;max-width:100%}.col-tablet-1{flex:0 0 8.3333333333%;max-width:8.3333333333%}.col-tablet-2{flex:0 0 16.6666666667%;max-width:16.6666666667%}.col-tablet-3{flex:0 0 25%;max-width:25%}.col-tablet-4{flex:0 0 33.3333333333%;max-width:33.3333333333%}.col-tablet-5{flex:0 0 41.6666666667%;max-width:41.6666666667%}.col-tablet-6{flex:0 0 50%;max-width:50%}.col-tablet-7{flex:0 0 58.3333333333%;max-width:58.3333333333%}.col-tablet-8{flex:0 0 66.6666666667%;max-width:66.6666666667%}.col-tablet-9{flex:0 0 75%;max-width:75%}.col-tablet-10{flex:0 0 83.3333333333%;max-width:83.3333333333%}.col-tablet-11{flex:0 0 91.6666666667%;max-width:91.6666666667%}.col-tablet-12{flex:0 0 100%;max-width:100%}}@media (min-width:64em){.col-desksm{flex-basis:0%;flex-grow:1;max-width:100%}.col-desksm-1{flex:0 0 8.3333333333%;max-width:8.3333333333%}.col-desksm-2{flex:0 0 16.6666666667%;max-width:16.6666666667%}.col-desksm-3{flex:0 0 25%;max-width:25%}.col-desksm-4{flex:0 0 33.3333333333%;max-width:33.3333333333%}.col-desksm-5{flex:0 0 41.6666666667%;max-width:41.6666666667%}.col-desksm-6{flex:0 0 50%;max-width:50%}.col-desksm-7{flex:0 0 58.3333333333%;max-width:58.3333333333%}.col-desksm-8{flex:0 0 66.6666666667%;max-width:66.6666666667%}.col-desksm-9{flex:0 0 75%;max-width:75%}.col-desksm-10{flex:0 0 83.3333333333%;max-width:83.3333333333%}.col-desksm-11{flex:0 0 91.6666666667%;max-width:91.6666666667%}.col-desksm-12{flex:0 0 100%;max-width:100%}}@media (min-width:80em){.col-deskxl{flex-basis:0%;flex-grow:1;max-width:100%}.col-deskxl-1{flex:0 0 8.3333333333%;max-width:8.3333333333%}.col-deskxl-2{flex:0 0 16.6666666667%;max-width:16.6666666667%}.col-deskxl-3{flex:0 0 25%;max-width:25%}.col-deskxl-4{flex:0 0 33.3333333333%;max-width:33.3333333333%}.col-deskxl-5{flex:0 0 41.6666666667%;max-width:41.6666666667%}.col-des ...

# %% [markdown]
# **Observación**: el *status_code* es un número que nos dice cómo nos fue al querer conectarnos con la página. *200* significa todo está bien!. Probablemente estan familiarizados con el *404* que aparece cuando una página no existe. Más info aquí: https://www.w3schools.com/tags/ref_httpmessages.asp

# %% [markdown]
# Listo! La información que nos dió el request es todo con lo que contamos. Ahora no queda otra que arremangarse y trabajar con esto. Para eso, *BeautifulSoup* nos da bastantes facilidades. Primero creamos la sopa:

# %%
# soup es un objeto manipulable creado a partir del contenido de la página y BeautifulSoup
soup = BS(response.content)

print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="es"><head><meta charset="utf-8"/><meta content="width=device-width,initial-scale=1.0,minimum-scale=0.5,maximum-scale=5.0,user-scalable=yes" name="viewport"/><meta content="#ffffff" name="theme-color"/><title>Últimas noticias de Argentina y el mundo - LA NACION</title><link as="image" fetchpriority="high" href="https://www.lanacion.com.ar/resizer/v2/juan-schiaretti-y-sergio-massa-en-el-segundo-Y6OVNITB3FF3XFITF3T73AGHFU.jpg?auth=8b161b934a382db1fd99319b003ea190708953cd64c6f6cd8a9e6fb8d132bf22&amp;width=488&amp;height=325&amp;quality=70&amp;smart=true" media="(min-width: 768px)" rel="preload"/><link as="image" fetchpriority="high" href="https://www.lanacion.com.ar/resizer/v2/juan-schiaretti-y-sergio-massa-en-el-segundo-Y6OVNITB3FF3XFITF3T73AGHFU.jpg?auth=8b161b934a382db1fd99319b003ea190708953cd64c6f6cd8a9e6fb8d132bf22&amp;width=420&amp;height=280&amp;quality=70&amp;smart=true" media="(max-width: 767px)" rel="preload"/><style>
# @font-face {font-family:'Prumo';src:url('/pf/resources/fonts/prumo/Prumo-LNVF.woff2?d=1374') format('woff2-variations'); font-weight: 90; font-display: swap;}
# @font-face {font-family:'Prumo Italic';src:url('/pf/resources/fonts/prumo/Prumo-ItalicLNVF.woff2?d=1374') format('woff2-variations'); font-weight: 90; font-display: swap;}
# .--prumo{font-family:"Prumo","Georgia"}.--font-primary{font-family:"Prumo","Georgia"}.row{display:flex;flex-wrap:wrap;width:100%}[class*=col-]{width:100%;position:relative}.col{flex-basis:0%;flex-grow:1;max-width:100%}.col-1{flex:0 0 8.3333333333%;max-width:8.3333333333%}.col-2{flex:0 0 16.6666666667%;max-width:16.6666666667%}.col-3{flex:0 0 25%;max-width:25%}.col-4{flex:0 0 33.3333333333%;max-width:33.3333333333%}.col-5{flex:0 0 41.6666666667%;max-width:41.6666666667%}.col-6{flex:0 0 50%;max-width:50%}.col-7{flex:0 0 58.3333333333%;max-width:58.3333333333%}.col-8{flex:0 0 66.6666666667%;max-width:66.6666666667%}.col-9{flex:0 0 75%;max-width:75%}.col-10{flex:0 0 83.3333333333%;max-width:83.3333333333%}.col-11{flex:0 0 91.6666666667%;max-width:91.6666666667%}.col-12{flex:0 0 100%;max-width:100%}@media (min-width:768px){.col-tablet{flex-basis:0%;flex-grow:1;max-width:100%}.col-tablet-1{flex:0 0 8.3333333333%;max-width:8.3333333333%}.col-tablet-2{flex:0 0 16.6666666667%;max-width:16.6666666667%}.col-tablet-3{flex:0 0 25%;max-width:25%}.col-tablet-4{flex:0 0 33.3333333333%;max-width:33.3333333333%}.col-tablet-5{flex:0 0 41.6666666667%;max-width:41.6666666667%}.col-tablet-6{flex:0 0 50%;max-width:50%}.col-tablet-7{flex:0 0 58.3333333333%;max-width:58.3333333333%}.col-tablet-8{flex:0 0 66.6666666667%;max-width:66.6666666667%}.col-tablet-9{flex:0 0 75%;max-width:75%}.col-tablet-10{flex:0 0 83.3333333333%;max-width:83.3333333333%}.col-tablet-11{flex:0 0 91.6666666667%;max-width:91.6666666667%}.col-tablet-12{flex:0 0 100%;max-width:100%}}@media (min-width:64em){.col-desksm{flex-basis:0%;flex-grow:1;max-width:100%}.col-desksm-1{flex:0 0 8.3333333333%;max-width:8.3333333333%}.col-desksm-2{flex:0 0 16.6666666667%;max-width:16.6666666667%}.col-desksm-3{flex:0 0 25%;max-width:25%}.col-desksm-4{flex:0 0 33.3333333333%;max-width:33.3333333333%}.col-desksm-5{flex:0 0 41.6666666667%;max-width:41.6666666667%}.col-desksm-6{flex:0 0 50%;max-width:50%}.col-desksm-7{flex:0 0 58.3333333333%;max-width:58.3333333333%}.col-desksm-8{flex:0 0 66.6666666667%;max-width:66.6666666667%}.col-desksm-9{flex:0 0 75%;max-width:75%}.col-desksm-10{flex:0 0 83.3333333333%;max-width:83.3333333333%}.col-desksm-11{flex:0 0 91.6666666667%;max-width:91.6666666667%}.col-desksm-12{flex:0 0 100%;max-width:100%}}@media (min-width:80em){.col-deskxl{flex-basis:0%;flex-grow:1;max-width:100%}.col-deskxl-1{flex:0 0 8.3333333333%;max-width:8.3333333333%}.col-deskxl-2{flex:0 0 16.6666666667%;max-width:16.6666666667%}.col-deskxl-3{flex:0 0 25%;max-width:25%}.col-deskxl-4{flex:0 0 33.3333333333%;max-width:33.3333333333%}.col-deskxl-5{flex:0 0 41.6666666667%;max-width:41.6666666667%}.col-deskxl-6{flex:0 0 50%;max-width:50%}.col-deskxl-7{flex:0 0 58.3333333333%;max-width:58.3333333333%}.col-deskxl-8{flex:0 0 66.6666666667%;max-width:66.6666666667%}.col-deskxl-9{flex:0 0 75%;max-width:75%}.col-deskxl-10{flex:0 0 83.3333333333%;max-width:83.3333333333%}.col-deskxl-11{flex:0 0 91.6666666667%;max-width:91.6666666667%}.col-deskxl-12{flex:0 0 100%;max-width:100%}.offset-deskxl-1{margin-left:8.3333333333%}}[class*=row-gap]{display:grid;grid-column-gap:1rem;grid-row-gap:2rem}@media (min-width:83.75em){[class*=row-gap]{grid-column-gap:2.5rem}}.row-gap-4{grid-template-columns:1fr 1fr 1fr 1fr}.row-gap-3{grid-template-columns:1fr 1fr 1fr}.row-gap-2{grid-template-columns:1fr 1fr}@media (min-width:48em){.row-gap-tablet-4{grid-template-columns:1fr 1fr 1fr 1fr}.row-gap-tablet-3{grid-template-columns:1fr 1fr 1fr}.row-gap-tablet-2{grid-template-columns:1fr 1fr}}@media (min-width:64em){.row-gap-desksm-5{grid-template-columns:1fr 1fr 1fr 1fr 1fr}.row-gap-desksm-4{grid-template-columns:1fr 1fr 1fr 1fr}.row-gap-desksm-3{grid-template-columns:1fr 1fr 1fr}.row-gap-desksm-2{grid-template-columns:1fr 1fr}}@media (min-width:80em){.row-gap-deskxl-4{grid-template-columns:1fr 1fr 1fr 1fr}.row-gap-deskxl-3{grid-template-columns:1fr 1fr 1fr}.row-gap-deskxl-2{grid-template-columns:1fr 1fr}}.lay-sidebar{display:flex;fle ...
#             Array.from = Array.from || (function() {
#                 var a = Object.prototype.toString,
#                     b = function(f) { return 'function' == typeof f || '[object Function]' === a.call(f) },
#                     c = function(f) { var g = +f; return isNaN(g) ? 0 : 0 != g && isFinite(g) ? (0 < g ? 1 : -1) * Math.floor(Math.abs(g)) : g },
#                     d = Math.pow(2, 53) - 1,
#                     e = function(f) { var g = c(f); return Math.min(Math.max(g, 0), d) };
#                 return function(g) {
#                     var h = this,
#                         i = Object(g);
#                     if (null == g) throw new TypeError('Array.from requires an array-like object - not null or undefined');
#                     var l, j = 1 < arguments.length ? arguments[1] : void 0;
#                     if ('undefined' != typeof j) {
#                         if (!b(j)) throw new TypeError('Array.from: when provided, the second argument must be a function');
#                         2 < arguments.length && (l = arguments[2])
#                     }
#                     for (var p, m = e(i.length), n = b(h) ? Object(new h(m)) : Array(m), o = 0; o < m;)
#                     p = i[o], n[o] = j ? 'undefined' == typeof l ? j(p, o) : j.call(l, p, o) : p, o += 1;
#                     return n.length = m, n
#                 }
#             }());
#
#             metarefresh = localStorage.getItem('CDmetaRefresh');
#
#             metarefresh = metarefresh != null ? 'yes' : 'no';
#
#             if (metarefresh === 'yes') {
#                 localStorage.removeItem('CDmetaRefresh');
#             }
#
#             var dataLayer = [
#                 {
#                     "metarefresh": metarefresh,
#                     "pagetype": "home",
#                 }
#             ];
#
#         </script><script async="" type="text/javascript">
#     const getMyCookie = function getCookie(nameCookie) {
#     if (!nameCookie) return undefined;
#     var value = "; ".concat(typeof document !== 'undefined' ? document.cookie : '');
#     var parts = value.split("; ".concat(nameCookie, "="));
#     return parts.length === 2 ? parts.pop().split(';').shift() : undefined;
#   };
#
#     const gaIdCookie = getMyCookie('_ga');
#     const googleAnalyticsId =  gaIdCookie && gaIdCookie.split('.').splice(2,2).join('.');
#     const usuarioEmail = getMyCookie('usuarioemail');
#
#     (function (h, o, u, n, d) {
#         h = h[d] = h[d] || {
#           q: [],
#           onReady: function (c) {
#             h.q.push(c);
#           },
#         };
#         d = o.createElement(u);
#         d.async = 1;
#         d.src = n;
#         n = o.getElementsByTagName(u)[0];
#         n.parentNode.insertBefore(d, n);
#       })(
#         window,
#         document,
#         "script",
#         "https://www.datadoghq-browser-agent.com/datadog-logs-v4.js",
#         "DD_LOGS"
#       );
#       DD_LOGS.onReady(function () {
#         DD_LOGS.init({
#           clientToken: "pubaa01cb67f0a687a6eba4718413593f4f",
#           site: "datadoghq.com",
#           forwardErrorsToLogs: true,
#           sampleRate: 1,
#           service: "lanacion-arc",
#           env: "prod",
#           version: "1374",
#           trackSessionAcrossSubdomains: false,
#         });
#
#         googleAnalyticsId && DD_LOGS.logger.addContext('user.gaId', googleAnalyticsId);
#         usuarioEmail && DD_LOGS.logger.addContext('user.email', usuarioEmail);
#
#         if ("prod" !== "prod")
#           console.log(
#             `Datadog initialized. Version: 1374, sampleRate: 1, env: prod`
#           );
#       });
#     </script><script async="" type="text/javascript">
#     (function (h, o, u, n, d) {
#         h = h[d] = h[d] || {
#           q: [],
#           onReady: function (c) {
#             h.q.push(c);
#           },
#         };
#         d = o.createElement(u);
#         d.async = 1;
#         d.src = n;
#         n = o.getElementsByTagName(u)[0];
#         n.parentNode.insertBefore(d, n);
#       })(
#         window,
#         document,
#         "script",
#         "https://www.datadoghq-browser-agent.com/datadog-rum-v4.js",
#         "DD_RUM"
#       );
#
#       DD_RUM.onReady(function () {
#         DD_RUM.init({
#           clientToken: "pubaa01cb67f0a687a6eba4718413593f4f",
#           applicationId: "bcea4545-f033-4b09-ab27-30995db5acb0",
#           site: "datadoghq.com",
#           service: "lanacion-arc",
#           env: "prod",
#           version: "1374",
#           sampleRate: 0.15,
#           sessionReplaySampleRate: 30,
#           trackResources: true,
#           trackLongTasks: true,
#           trackInteractions: true,
#           trackFrustrations: true,
#           trackSessionAcrossSubdomains: false,
#         });
#
#         DD_RUM.startSessionReplayRecording();
#
#         if (googleAnalyticsId || usuarioEmail) {
#           DD_RUM.setUser({
#             ...(googleAnalyticsId && { gaId: googleAnalyticsId }),
#             ...(usuarioEmail && { email: usuarioEmail })
#           });
#         }
#
#         if ("prod" !== "prod")
#             console.log(
#               `Datadog RUM initialized. Version: 1374, sampleRate: 0.15, env: prod`
#             );
#       });</script><script async="" type="text/javascript">
#     function getTemplateType(layoutName) {
#     if (['LN-Home_Main', 'LN10-Home_Main'].includes(layoutName)) return 'home';
#     if (layoutName.includes('nota')) return 'article';
#     return 'section';
#   }
#     const permutiveGetCookie = function getCookie(nameCookie) {
#     if (!nameCookie) return undefined;
#     var value = "; ".concat(typeof document !== 'undefined' ? document.cookie : '');
#     var parts = value.split("; ".concat(nameCookie, "="));
#     return parts.length === 2 ? parts.pop().split(';').shift() : undefined;
#   };
#     const userCookie = permutiveGetCookie('ProductoPremiumId') || [];
#     const isUserLoggedIn = !!permutiveGetCookie('token');
#     const isUserSubscribed = userCookie.includes('2');
#
#     const user = {
#         loggedIn: isUserLoggedIn,
#         suscribed: isUserSubscribed,
#         ...(userCookie &&
#             userCookie.length && {typeOfSuscription: userCookie.split(',')})
#       }
#
#
#     !function(e,o,n,i){if(!e){e=e||{},window.permutive=e,e.q=[];var t=function(){return([1e7]+-1e3+-4e3+-8e3+-1e11)
#     .replace(/[018]/g,function(e){return(e^(window.crypto||window.msCrypto).getRandomValues(new Uint8Array(1))[0]&15>>e/4)
#     .toString(16)})};e.config=i||{},e.config.apiKey=o,e.config.workspaceId=n,e.config.environment=e.config.environment||"production",
#     (window.crypto||window.msCrypto)&&(e.config.viewId=t());
#     for(var g=["addon","identify","track","trigger","query","segment","segments","ready","on","once","user","consent"],
#     r=0;r<g.length;r++){var w=g[r];e[w]=function(o){return function(){var n=Array.prototype.slice.call(arguments,0);
#     e.q.push({functionName:o,arguments:n})}}(w)}}}
#     (window.permutive,"2f46069c-4d57-4535-9aeb-582079606f3b","867f8423-d142-4fd1-ae8d-1a9bbbdf2358",{"consentRequired": false});
#     window.googletag=window.googletag||{},window.googletag.cmd=window.googletag.cmd||[],window.googletag.cmd.push(function()
#     {if(0===window.googletag.pubads().getTargeting("permutive").length){var e=window.localStorage.getItem("_pdfps");window.googletag.pubads()
#     .setTargeting("permutive",e?JSON.parse(e):[]);var o=window.localStorage.getItem("permutive-id");o&&(window.googletag.pubads()
#     .setTargeting("puid",o),window.googletag.pubads().setTargeting("ptime",Date.now().toString())),window.permutive.config.viewId&&window
#     .googletag.pubads().setTargeting("prmtvvid",window.permutive.config.viewId),window.permutive.config.workspaceId&&window.googletag.pubads()
#     .setTargeting("prmtvwid",window.permutive.config.workspaceId)}});
#     permutive.addon('web',{
#       "page": {
#         "classifications_watson": {
#           "categories": "$alchemy_taxonomy",
#           "concepts": "$alchemy_concepts",
#           "emotion": "$alchemy_document_emotion",
#           "entities": "$alchemy_entities",
#           "keywords": "$alchemy_keywords",
#           "sentiment": "$alchemy_document_sentiment"
#         },
#         "type": "home",
#         "user": user,
#
#       }
#     });
#     </script><script async="" src="https://867f8423-d142-4fd1-ae8d-1a9bbbdf2358.edge.permutive.app/867f8423-d142-4fd1-ae8d-1a9bbbdf2358-web.js"></script><script defer="" type="text/javascript">((w,l)=>{w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});})(window,'dataLayer');</script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-GHV6"></script><script defer="" type="text/javascript">var _comscore = _comscore || [];_comscore.push({"c1":"2","c2":"6906398"});(function() {
#                 var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#                 s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";el.parentNode.insertBefore(s, el);
#             })();</script><noscript><img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6906398&amp;cv=2.0&amp;cj=1"/></noscript><script async="" src=" https://securepubads.g.doubleclick.net/tag/js/gpt.js?network-code=133919216"></script><script async="" id="googlePublisherTag-metadata" type="text/javascript">
#         const createHash = function createHash(data) {
#   var encoder = new TextEncoder();
#   var dataBuffer = encoder.encode(data);
#   return crypto.subtle ? crypto.subtle.digest('SHA-256', dataBuffer).then(function (hashBuffer) {
#     if (hashBuffer) {
#       var hashArray = Array.from(new Uint8Array(hashBuffer));
#       var hashHex = hashArray.map(function (_byte) {
#         return _byte.toString(16).padStart(2, '0');
#       }).join('');
#       return hashHex;
#     }
#   }) : Promise.reject('crypto.subtle only works on HTTPS');
# };
#         const googleTagGetCookie = function getCookie(nameCookie) {
#     if (!nameCookie) return undefined;
#     var value = "; ".concat(typeof document !== 'undefined' ? document.cookie : '');
#     var parts = value.split("; ".concat(nameCookie, "="));
#     return parts.length === 2 ? parts.pop().split(';').shift() : undefined;
#   };
#         const googleTagUserCookie = googleTagGetCookie('ProductoPremiumId') || [];
#         const googleTagEmailCookie = googleTagGetCookie('usuarioemail') || '';
#         const googleTagSuscriptionType = userCookie.includes('2') ? 'suscriptor' : 'no suscriptor';
#
#             var pbjs = pbjs || {};
#             pbjs.que = pbjs.que || [];
#
#             (window.googletag = window.googletag || { cmd: [] });
#                 googletag.cmd.push(function() {
#                     if (googleTagEmailCookie) {
#                         createHash(googleTagEmailCookie)
#                         .then(hash => {
#                             googletag.pubads().setPublisherProvidedId(hash);
#                         })
#                     }
#
#                     googletag.enableServices();
#                     googletag.pubads().setTargeting('tags_nuevos', []);
#                     googletag.pubads().setTargeting('usuario_tipo', googleTagSuscriptionType);
#                     googletag.pubads().setTargeting('seccion', 'acumulado');
#                     //googletag.pubads().setTargeting('adstest', testQueryString());
#                     googletag.pubads().setTargeting('sitio', 'lanacion');
#                 }
#             )
#     </script><script async="" type="text/javascript">
#     //load the apstag.js library
#     !(function(a9, a, p, s, t, A, g) {
#         if (a[a9]) return;
#         function q(c, r) {
#             a[a9]._Q.push([c, r]);
#         }
#         a[a9] = {
#             init: function() {
#                 q('i', arguments);
#             },
#             fetchBids: function() {
#                 q('f', arguments);
#             },
#             setDisplayBids: function() {},
#             targetingKeys: function() {
#                 return [];
#             },
#             _Q: []
#         };
#         A = p.createElement(s);
#         A.async = !0;
#         A.src = t;
#         g = p.getElementsByTagName(s)[0];
#         g.parentNode.insertBefore(A, g);
#     })(
#         'apstag',
#         window,
#         document,
#         'script',
#         '//c.amazon-adsystem.com/aax2/apstag.js'
#     );
#
#     // initialize the apstag.js library on the page to allow bidding
#     apstag.init({
#         pubID: '8670178e-76cd-476d-9c5f-0ed20920dd2a', // enter your pub ID here as shown above, it must within quotes
#         adServer: 'googletag'
#     });</script><meta content="154042854349421" property="fb_app_id"/><meta content="website" property="og:type"/><meta content="Últimas noticias de Argentina y el mundo" property="og:title"/><meta content="LA NACION ofrece las últimas noticias, fotos y videos de la Argentina y el mundo. Política, economía, deportes y toda la información en tiempo real." property="og:description"/><meta content="https://arc-static.glanacion.com/pf/resources/images/placeholderLN.jpg?d=1374" property="og:image"/><meta content="https://www.lanacion.com.ar/" property="og:url"/><meta content="LA NACION" property="og:site_name"/><link href="https://www.lanacion.com.ar/" rel="canonical"/><meta content="Últimas noticias de Argentina y el mundo - LA NACION" name="title"/><meta content="LA NACION ofrece las últimas noticias, fotos y videos de la Argentina y el mundo. Política, economía, deportes y toda la información en tiempo real." name="description"/><script type="application/ld+json">{
#         "@context": "http://schema.org",
#         "@type": "NewsMediaOrganization",
#         "name": "LA NACION",
#         "url": "https://www.lanacion.com.ar/",
#         "description": "Últimas noticias de Argentina y el mundo – LA NACION",
#         "alternateName": "LN",
#         "diversityPolicy": "https://www.lanacion.com.ar/sociedad/diversidad-redaccion-nid2413327/",
#         "ethicsPolicy": "https://www.lanacion.com.ar/sociedad/la-nacion-mision-estructura-empresarial-principios-eticos-nid2393569/",
#         "masthead": "https://www.lanacion.com.ar/sociedad/equipo-editorial-la-nacion-nid2390490/",
#         "publishingPrinciples": "https://www.lanacion.com.ar/sociedad/los-veinte-20-principios-del-periodismo-la-nid2390521/",
#         "verificationFactCheckingPolicy": "https://www.lanacion.com.ar/sociedad/verificacion-chequeo-datos-nid2406825/",
#         "foundingDate": "1870-01-04",
#         "logo": {
#             "@context": "https://schema.org",
#             "@type": "ImageObject",
#             "url": "https://arc-static.glanacion.com/pf/resources/images/placeholderLN-112_amp.jpg?d=1374",
#             "height": 112,
#             "width": 112
#           },
#         "sameAs": [
#           "https://www.facebook.com/lanacion/",
#           "https://www.instagram.com/lanacioncom/",
#           "https://twitter.com/LANACION"
#         ]
#       }</script><script type="application/ld+json">{
#         "@context":"http://schema.org",
#         "@type":"WebSite",
#         "url":"https://www.lanacion.com.ar/"
#     }</script><link href="/pf/resources/images/favicon.ico?d=1374" rel="shortcut icon" type="image/x-icon"/><link href="/pf/resources/images/favicon-16.png?d=1374" rel="icon" sizes="16x16" type="image/png"/><link href="/pf/resources/images/favicon-32.png?d=1374" rel="icon" sizes="32x32" type="image/png"/><link href="/pf/resources/images/favicon-192.png?d=1374" rel="shortcut icon" sizes="192x192" type="image/png"/><link href="/pf/resources/images/favicon-512.png?d=1374" rel="shortcut icon" sizes="512x512" type="image/png"/><link href="/pf/resources/images/favicon-192.png?d=1374" rel="apple-touch-icon"/><link href="/pf/resources/images/favicon-512.png?d=1374" rel="apple-touch-icon" sizes="512x512"/><link href="/manifest.json" rel="manifest"/>
# <script>(window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"false","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false","rua.isuxp":"false","rua.texp":"norulematch"}]);</script>
# <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="FPXUV-CWEKR-ELG8D-URM4T-QZGQK",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"FPXUV-CWEKR-ELG8D-URM4T-QZGQK";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="ejfg3bix3oneozkfceqa-f-8fb437529-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"36","ak.cp":"847416","ak.ai":parseInt("541075",10),"ak.ol":"0","ak.cr":83,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"b066f551","ak.r":45276,"ak.a2":n,"ak.m":"dscr","ak.n":"ff","ak.bpcip":"34.74.109.0","ak.cport":54756,"ak.gh":"23.58.124.71","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1699025184","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"171","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head><body class="ln"><noscript><iframe height="0" src="https://www.googletagmanager.com/gtm.js?id=GTM-GHV6" style="display:none;visibility:hidden" width="0"></iframe></noscript>< ...
#                             window.addEventListener('DOMContentLoaded', () => {
#                                 document.getElementById('comercial_dsk_btnCloseAd').onclick = function() {
#
#                                     this.parentNode && this.parentNode.classList.add('none')
#                                 };
#                             });
#                             </script></div><script type="text/javascript">
#                 window.addEventListener('DOMContentLoaded', () => {
#                     setTimeout(function(){
#
#                         const bannerComercial = document.getElementById("comercial_dsk");
#                         bannerComercial && bannerComercial.parentNode.classList.add('none');
#                     },12000)
#                 })
#             </script><div class="ln-banner-container --comercial_mob --comercial none"><div class="ln-banner" data-prebid-enabled="false" data-size="[]" data-sizemap="[]" data-subscription="false" data-without-hide="false" id="comercial_mob"></div><button class="button ln-button --arial --primary --md" data-event="LinkClick" data-section="Comercial-home" id="comercial_mob_btnCloseAd" type="button">CERRAR</button><script>
#                             window.addEventListener('DOMContentLoaded', () => {
#                                 document.getElementById('comercial_mob_btnCloseAd').onclick = function() {
#
#                                     this.parentNode && this.parentNode.classList.add('none')
#                                 };
#                             });
#                             </script></div><script type="text/javascript">
#                 window.addEventListener('DOMContentLoaded', () => {
#                     setTimeout(function(){
#
#                         const bannerComercial = document.getElementById("comercial_mob");
#                         bannerComercial && bannerComercial.parentNode.classList.add('none');
#                     },12000)
#                 })
#             </script><div class="wrapper homepage"><div class="ln-banner-container --megatop_dsk --megatop"><div class="ln-banner" data-prebid-enabled="false" data-size="[]" data-sizemap="[]" data-subscription="false" data-without-hide="false" id="megatop_dsk"></div></div><div class="ln-banner-container --megatop_tab --megatop"><div class="ln-banner" data-prebid-enabled="false" data-size="[]" data-sizemap="[]" data-subscription="false" data-without-hide="false" id="megatop_tab"></div></div><script type="text/javascript">
#                     window.addEventListener('DOMContentLoaded', () => {
#                         const banners = Array.from(document.querySelectorAll('.ln-banner-container.--megatop_dsk.--megatop,.ln-banner-container.--megatop_tab.--megatop')) || [];
#                         const header = document.querySelector("#undefined");
#                         const viewportLimit = document.querySelector('section[data-section="pre-apertura"]') || {};
#                         const content = document.querySelector('#content') || {};
#                         let paddingTop = 0;
#                         let oldScrollY = window.scrollY;
#
#                         const handleSticky = (banner = {}) => {
#                             const isScrollUp = oldScrollY > window.scrollY
#                             const { top: topViewportLimit } = viewportLimit.getBoundingClientRect();
#                             const viewPoint = topViewportLimit - banner.clientHeight - (undefined ? header.clientHeight : 0);
#
#                             if (viewPoint <= 0 && banner.classList.contains('--sticky')) {
#                                 if  (content instanceof Element){
#                                     paddingTop = parseFloat(window.getComputedStyle(content).getPropertyValue('padding-top')) || 0;
#                                 }
#                                 banner.classList.remove('--sticky');
#                                 banner.style.top = Math.abs(viewportLimit.offsetTop - banner.clientHeight - paddingTop) + 'px';
#                                 banner.style.position = 'relative';
#                             } else if (viewPoint > 0 && !banner.classList.contains('--sticky')) {
#                                 banner.classList.add('--sticky');
#                                 banner.style.cssText = '';
#                             }
#
#                             if (isScrollUp) {
#                                 banner.classList.remove('--sticky');
#                                 banner.style.top = '0';
#                             }
#                         }
#
#                         window.addEventListener('scroll', () => {
#                             banners.forEach(handleSticky)
#                             oldScrollY = window.scrollY;
#                         })
#                     })
#                 </script><div class="--no-app"><div data-section="cabezal"><div class="hidden"><div class="ln-pre-header flex ai-center --tablet-none"><div class="lay-container"><div class="flex ai-center"><a class="link ln-link --weather mr-16" data-event="e_linkclick" data-section="MenuLN" href="/clima/" target="_self" title="Clima"><div class="ln-weather flex ai-center jc-start w-max"><span class="text ln-text place mr-8 --font-xs">Capital Federal</span><i class="icon mr-4 --icon-16"><svg fill="none" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.5 6a6.5 6.5 0 1 0 0 13h7a4.5 4.5 0 1 0-.957-8.898A6.502 6.502 0 0 0 9.5 6Zm7 15h-7a8.5 8.5 0 1 1 7.215-12.997A6.5 6.5 0 0 1 16.5 21Z" fill="#272727"></path></svg></i><span class="text ln-text --font-bold --font-xs">16.6º</span></div></a><div class="topics-container flex ai-center"><nav class="topics flex --scroll-x ai-center"><span class="text ln-text mr-8 --font-xs">HOY: </span><ul class="tag-list inline-flex"><li class="w-max flex ai-center"><a class="link mr-8 --font-bold --font-xs --unstyled" data-event="e_linkclick" data-section="MenuLN" href="https://www.lanacion.com.ar/tema/elecciones-2023/" target="_self" title="Elecciones 2023">Elecciones 2023</a></li><li class="w-max flex ai-center"><a class="link mr-8 --font-bold --font-xs --unstyled" data-event="e_linkclick" data-section="MenuLN" href="https://www.lanacion.com.ar/dolar-hoy/" target="_self" title="Dólar hoy">Dólar hoy</a></li><li class="w-max flex ai-center"><a class="link mr-8 --font-bold --font-xs --unstyled" data-event="e_linkclick" data-section="MenuLN" href="https://www.lanacion.com.ar/tema/guerra-en-medio-oriente/" target="_self" title="Guerra en Medio Oriente">Guerra en Medio Oriente</a></li><li class="w-max flex ai-center"><a class="link mr-8 --font-bold --font-xs --unstyled" data-event="e_linkclick" data-section="MenuLN" href="https://www.lanacion.com.ar/tema/copa-libertadores-tid47535/" target="_self" title="Copa Libertadores">Copa Libertadores</a></li><li class="w-max flex ai-center"><a class="link mr-8 --font-bold --font-xs --unstyled" data-event="e_linkclick" data-section="MenuLN" href="https://www.lanacion.com.ar/tema/copa-de-la-liga-2023/" target="_self" title="Fútbol argentino">Fútbol argentino</a></li></ul></nav></div></div></div></div><script>
#                     window.addEventListener('DOMContentLoaded', () => {
#                         function createDynamicLabel() {
#   var text = arguments.length > 0 && arguments[0] !== undefined ? arguments[0] : '';
#   return text.toLowerCase().replace(/ /g, '_').replace(/á/g, 'a').replace(/é/g, 'e').replace(/í/g, 'i').replace(/ó/g, 'o').replace(/ú/g, 'u');
# }
#                         function addEventToDataLayer() {
#   var _ref = arguments.length > 0 && arguments[0] !== undefined ? arguments[0] : {},
#       label = _ref.label,
#       action = _ref.action,
#       category = _ref.category,
#       event = _ref.event;
#
#   var HOME_LN10 = 'home_ln10';
#   var E_LINK_CLICK = 'e_linkclick';
#   window.dataLayer && window.dataLayer.push({
#     event: event || E_LINK_CLICK,
#     dynamic_category: category || HOME_LN10,
#     dynamic_action: action,
#     dynamic_label: label
#   });
# }
#                         function addEventListeners(element, payload, callback) {
#   var CLICK = 'click';
#   var AUX_CLICK = 'auxclick';
#
#   var defaultCallback = function defaultCallback() {
#     return addEventToDataLayer(payload);
#   };
#
#   if (element) {
#     element.addEventListener(CLICK, callback || defaultCallback);
#     element.addEventListener(AUX_CLICK, callback || defaultCallback);
#   }
# }
#                         function setEventsWeather() {
#   var linkWeather = window.document.querySelector('.link.ln-link.--weather');
#   var payload = {
#     action: 'header_clima',
#     label: 'clima'
#   };
#   addEventListeners(linkWeather, payload);
# }
#                         function setEventsTopics() {
#   var topics = window.document.querySelectorAll('.tag-list a');
#   topics.forEach(function (topicElement) {
#     var payload = {
#       action: 'header_temas_hoy',
#       label: createDynamicLabel(topicElement.title)
#     };
#     addEventListeners(topicElement, payload);
#   });
# }
#
#                         setEventsWeather();
#                         setEventsTopics();
#                     });
#                 </script></div></div><div class="header-container"><header class="ln-header --unlogged"><div class="ln-main-header border border-thin border-bottom border-light-300"><div class="lay-container"><div class="flex ai-center jc-between"><div class="left-actions flex --tablet-lg-none"><button class="button ln-button secciones --arial --secondary --md" title="Secciones" type="button"><i class="icon --menu --icon-24" icon="menu"><svg fill="none" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M3 5a1 1 0 0 1 1-1h16a1 1 0 1 1 0 2H4a1 1 0 0 1-1-1Zm0 7a1 1 0 0 1 1-1h16a1 1 0 1 1 0 2H4a1 1 0 0 1-1-1Zm0 7a1 1 0 0 1 1-1h16a1 1 0 1 1 0 2H4a1 1 0 0 1-1-1Z" fill="#272727" fill-rule="evenodd"></path></svg></i><span class="text ln-text --desktop-only --font-xs">SECCIONES</span></button><label class="button ln-button --secondary search --md" for="queryly_toggle" id="querylyButton" title="Ir al buscador"><i class="icon --icon-24"><svg fill="none" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="m18.031 16.617 4.283 4.282-1.415 1.415-4.282-4.283A8.96 8.96 0 0 1 11 20c-4.968 0-9-4.032-9-9s4.032-9 9-9 9 4.032 9 9a8.96 8.96 0 0 1-1.969 5.617Zm-2.006-.742A6.977 6.977 0 0 0 18 11c0-3.868-3.133-7-7-7-3.868 0-7 3.132-7 7 0 3.867 3.132 7 7 7a6.977 6.977 0 0 0 4.875-1.975l.15-.15Z" fill="#272727"></path></svg></i></label></div><div class="center-actions flex ai-center"><a class="link ln-link logo-header flex" href="/" target="_self" title="Ir a la página principal"><div class="ln-banner-container --logo_header_dsk --logo none"><div class="ln-banner" data-prebid-enabled="false" data-size="[]" data-sizemap="[]" data-subscription="false" data-without-hide="true" id="logo_header_dsk"></div></div><div class="ln-banner-container --logo_header_dsk_sticky --logo_sticky_dsk none"><div class="ln-banner" data-prebid-enabled="false" data-size="[]" data-sizemap="[]" data-subscription="false" data-without-hide="true" id="logo_header_dsk_sticky"></div></div><div class="ln-banner-container --logo_header_tab --logo none"><div class="ln-banner" data-prebid-enabled="false" data-size="[]" data-sizemap="[]" data-subscription="false" data-without-hide="true" id="logo_header_tab"></div></div><div class="ln-banner-container --logo_header_mob --logo none"><div class="ln-banner" data-prebid-enabled="false" data-size="[]" data-sizemap="[]" data-subscription="false" data-without-hide="true" id="logo_header_mob"></div></div><svg viewbox="-15077.383 26 200 19.802" xmlns="http://www.w3.org/2000/svg"><g data-name="Logo LN" fill="#006998" id="Logo_LN" transform="translate(-15657.383 8)"><path d="M0,18.847v-1.3H3.26V1.294H0V0H13.036V1.294H9.445V17.551h.767c4.283,0,7.7-1.111,7.7-5.4v-.812h1.612v7.5Z" data-name="Path 1" id="Path_1" transform="translate(580 18.396)"></path><path d="M23.925,17.523,14.232,0H11.791L3.447,15.927a2.859,2.859,0,0,1-2.788,1.6H0v1.3H7.825v-1.3H6.41c-.821,0-1.534-.1-1.534-.98a1.746,1.746,0,0,1,.288-.8 L6.28,13.568h8.462l2.124,3.954H13.741v1.3H26.636v-1.3h-2.71ZM6.957,12.284l3.412-6.4h.278l3.417,6.4Z" data-name="Path 2" id="Path_2" transform="translate(600.654 18.594)"></path><path d="M0,18.847v-1.3H.944c1.134,0,2.2-.293,2.2-1.923V3.4A2.323,2.323,0,0,0,.669,1.294H.113V0H9.53L19.913,11.135h.075V2.816c0-1.027-.882-1.521-2.5-1.521 H16.51V0h8.048V1.294h-.79c-1.666,0-2.35.767-2.35,1.438V18.847H18.729L4.628,3.67H4.554v12.1c0,1.525.811,1.784,2.848,1.784h.63v1.3Z" data-name="Path 3" id="Path_3" transform="translate(639.742 18.396)"></path><path d="M23.929,17.523,14.25,0H11.8L3.449,15.927a2.843,2.843,0,0,1-2.787,1.6H0v1.3H7.851v-1.3H6.407c-.813,0-1.524-.1-1.524-.98a1.836,1.836,0,0,1,.283-.8 l1.123-2.171h8.474l2.106,3.954H13.745v1.3h12.89v-1.3H23.929ZM6.976,12.284l3.4-6.4h.292l3.4,6.4Z" data-name="Path 4" id="Path_4" transform="translate(663.9 18.594)"></path><path d="M20.464.508V7.193h-1.6c-.6-2.721-2.222-5.908-6.15-5.908C7.8,1.286,6.786,5.17,6.786,9.932c0,4.573.912,8.506,5.808,8.506,3.825,0,6.408-2.452,6.408-5.8  ...
#                     window.addEventListener('DOMContentLoaded', () => {
#                         function addEventToDataLayer() {
#   var _ref = arguments.length > 0 && arguments[0] !== undefined ? arguments[0] : {},
#       label = _ref.label,
#       action = _ref.action,
#       category = _ref.category,
#       event = _ref.event;
#
#   var HOME_LN10 = 'home_ln10';
#   var E_LINK_CLICK = 'e_linkclick';
#   window.dataLayer && window.dataLayer.push({
#     event: event || E_LINK_CLICK,
#     dynamic_category: category || HOME_LN10,
#     dynamic_action: action,
#     dynamic_label: label
#   });
# }
#                         function addEventListeners(element, payload, callback) {
#   var CLICK = 'click';
#   var AUX_CLICK = 'auxclick';
#
#   var defaultCallback = function defaultCallback() {
#     return addEventToDataLayer(payload);
#   };
#
#   if (element) {
#     element.addEventListener(CLICK, callback || defaultCallback);
#     element.addEventListener(AUX_CLICK, callback || defaultCallback);
#   }
# }
#                         function createDynamicLabel() {
#   var text = arguments.length > 0 && arguments[0] !== undefined ? arguments[0] : '';
#   return text.toLowerCase().replace(/ /g, '_').replace(/á/g, 'a').replace(/é/g, 'e').replace(/í/g, 'i').replace(/ó/g, 'o').replace(/ú/g, 'u');
# }
#                         function setEventSubscribe() {
#   var btnSuscribite = window.document.querySelector('#btnsuscribite');
#   var payload = {
#     action: 'header_logo',
#     label: 'suscribite'
#   };
#   addEventListeners(btnSuscribite, payload);
# }
#                         function setEventSignIn() {
#   var btnSignIn = window.document.querySelector('button[title="Iniciar sesión"]');
#   var payload = {
#     action: 'header_logo',
#     label: 'iniciar_sesion'
#   };
#   addEventListeners(btnSignIn, payload);
# }
#                         function setEventsSections() {
#   var sections = window.document.querySelectorAll('.dd-link');
#   sections.forEach(function (section) {
#     var payload = {
#       action: 'menu_secciones',
#       label: createDynamicLabel(section.innerHTML)
#     };
#     addEventListeners(section, payload);
#   });
# }
#                         function setEventSearch() {
#   var searchIcon = window.document.querySelector('#querylyButton');
#   var payload = {
#     action: 'header_logo',
#     label: 'buscar'
#   };
#   addEventListeners(searchIcon, payload);
# }
#
#                         setEventSubscribe();
#                         setEventSignIn();
#                         setEventsSections();
#                         setEventSearch();
#                     });
#                 </script></div></div></div><div class="hidden"><div class="ln-sub-header border border-thin border-bottom border-light-300"><div class="lay-container"><div class="flex ai-center jc-between"><div class="dollar-container --relative"><div class="--scroll-x"><ul class="dollar inline-flex"><li class="w-max flex ai-center"><a class="link ln-link --font-xs" href="https://www.lanacion.com.ar/dolar-hoy/" target="_self" title="Dólar oficial">Dólar oficial<span class="text ln-text mr-8 --font-bold"> $365,50</span></a></li><li class="w-max flex ai-center"><a class="link ln-link --font-xs" href="https://www.lanacion.com.ar/tema/dolar-blue-tid67294/" target="_self" title="Dólar blue">Dólar blue<span class="text ln-text mr-8 --font-bold"> $925,00</span></a></li><li class="w-max flex ai-center"><a class="link ln-link --font-xs" href="https://www.lanacion.com.ar/tema/dolar-turista-tid67475/" target="_self" title="Dólar turista">Dólar turista<span class="text ln-text mr-8 --font-bold"> $736,1</span></a></li><li class="w-max flex ai-center"><a class="link ln-link --font-xs" href="https://www.lanacion.com.ar/tema/dolar-ccl/" target="_self" title="Dólar CCL">Dólar CCL<span class="text ln-text mr-8 --font-bold"> $881,82</span></a></li></ul></div></div><div class="access-container --tablet-none"><ul class="access flex"><li class="w-max mr-16"><a class="link ln-link flex ai-center --font-xs" href="https://www.lanacion.com.ar/mis-notas/" target="_self" title="Ir a Mis notas"><i class="icon mr-4 --icon-20"><svg fill="none" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M5 2h14a1 1 0 0 1 1 1v19.143a.5.5 0 0 1-.766.424L12 18.03l-7.234 4.536A.5.5 0 0 1 4 22.143V3a1 1 0 0 1 1-1Zm13 2H6v15.432l6-3.761 6 3.761V4Z" fill="#272727"></path></svg></i>Mis notas</a></li><li class="w-max mr-16"><a class="link ln-link flex ai-center --font-xs" href="https://newsletter.lanacion.com.ar/?_ga=2.113114052.1174706434.1669633950-901996504.1663609274" target="_self" title="Ir a Newsletters"><i class="icon mr-4 --icon-20"><svg fill="none" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M2.243 6.854 11.49 1.31a1 1 0 0 1 1.029 0l9.238 5.545a.5.5 0 0 1 .243.429V20a1 1 0 0 1-1 1H3a1 1 0 0 1-1-1V7.283a.5.5 0 0 1 .243-.429ZM4 8.133V19h16V8.132l-7.996-4.8L4 8.132v.001Zm8.06 5.565 5.296-4.463 1.288 1.53-6.57 5.537-6.71-5.53 1.272-1.544 5.424 4.47Z" fill="#272727"></path></svg></i>Newsletters</a></li><li class="w-max mr-16"><a class="link ln-link flex ai-center --font-xs" href="https://club.lanacion.com.ar/?_ga=2.113114052.1174706434.1669633950-901996504.1663609274" target="_self" title="Ir a Club LA NACION"><i class="icon mr-4 --icon-20"><svg fill="none" viewbox="0 0 16 12" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M.679 11.009c.107.232.339.357.571.357a.41.41 0 0 0 .25-.072.638.638 0 0 0 .304-.839c-.018-.071-.054-.143-.09-.214A6.141 6.141 0 0 1 1.25 7.9c0-.803.16-1.589.482-2.374A6.006 6.006 0 0 1 4.93 2.33a6.142 6.142 0 0 1 2.339-.464c.803 0 1.59.143 2.34.464a6.006 6.006 0 0 1 3.196 3.197c.125.303.232.625.303.928.072.34.41.554.75.465a.608.608 0 0 0 .464-.75c-.107-.375-.214-.75-.375-1.108a7.282 7.282 0 0 0-3.857-3.857A7.396 7.396 0 0 0 7.25.634c-.964 0-1.929.196-2.821.571a7.238 7.238 0 0 0-2.304 1.572A7.242 7.242 0 0 0 0 7.902c0 .982.179 1.946.554 2.839.017.045.04.09.062.134.022.044.045.09.063.134Zm7.696-3.625h-4.16a.633.633 0 0 1-.626-.625c0-.34.286-.625.625-.625h4.161c.34 0 .625.285.625.625 0 .339-.268.625-.625.625Zm7 2.768H4.25a.633.633 0 0 1-.625-.625c0-.34.286-.625.625-.625h11.125c.34 0 .625.285.625.625 0 .339-.286.625-.625.625Z" fill="#272727" fill-rule="evenodd"></path></svg></i>Club LA NACION</a></li></ul></div></div></div></div><script>
#                     window.addEventListener('DOMContentLoaded', () => {
#                         function addEventToDataLayer() {
#   var _ref = arguments.length > 0 && arguments[0] !== undefined ? arguments[0] : {},
#       label = _ref.label,
#       action = _ref.action,
#       category = _ref.category,
#       event = _ref.event;
#
#   var HOME_LN10 = 'home_ln10';
#   var E_LINK_CLICK = 'e_linkclick';
#   window.dataLayer && window.dataLayer.push({
#     event: event || E_LINK_CLICK,
#     dynamic_category: category || HOME_LN10,
#     dynamic_action: action,
#     dynamic_label: label
#   });
# }
#                         function addEventListeners(element, payload, callback) {
#   var CLICK = 'click';
#   var AUX_CLICK = 'auxclick';
#
#   var defaultCallback = function defaultCallback() {
#     return addEventToDataLayer(payload);
#   };
#
#   if (element) {
#     element.addEventListener(CLICK, callback || defaultCallback);
#     element.addEventListener(AUX_CLICK, callback || defaultCallback);
#   }
# }
#                         function createDynamicLabel() {
#   var text = arguments.length > 0 && arguments[0] !== undefined ? arguments[0] : '';
#   return text.toLowerCase().replace(/ /g, '_').replace(/á/g, 'a').replace(/é/g, 'e').replace(/í/g, 'i').replace(/ó/g, 'o').replace(/ú/g, 'u');
# }
#                         function setEventsDollar() {
#   var dollars = window.document.querySelectorAll('.dollar a');
#   dollars.forEach(function (dollar) {
#     var payload = {
#       action: 'header_dolar',
#       label: createDynamicLabel(dollar.title)
#     };
#     addEventListeners(dollar, payload);
#   });
# }
#                         function setEventsAccess() {
#   var accesses = window.document.querySelectorAll('.access a');
#   accesses.forEach(function (access) {
#     var payload = {
#       action: 'header_accesos',
#       label: createDynamicLabel(access.text)
#     };
#     addEventListeners(access, payload);
#   });
# }
#
#                         setEventsDollar();
#                         setEventsAccess();
#                     });
# ...
#                     window.addEventListener('DOMContentLoaded', () => {
#                         function createDynamicLabel() {
#   var text = arguments.length > 0 && arguments[0] !== undefined ? arguments[0] : '';
#   return text.toLowerCase().replace(/ /g, '_').replace(/á/g, 'a').replace(/é/g, 'e').replace(/í/g, 'i').replace(/ó/g, 'o').replace(/ú/g, 'u');
# }
#                         function addEventToDataLayer() {
#   var _ref = arguments.length > 0 && arguments[0] !== undefined ? arguments[0] : {},
#       label = _ref.label,
#       action = _ref.action,
#       category = _ref.category,
#       event = _ref.event;
#
#   var HOME_LN10 = 'home_ln10';
#   var E_LINK_CLICK = 'e_linkclick';
#   window.dataLayer && window.dataLayer.push({
#     event: event || E_LINK_CLICK,
#     dynamic_category: category || HOME_LN10,
#     dynamic_action: action,
#     dynamic_label: label
#   });
# }
#                         function addEventListeners(element, payload, callback) {
#   var CLICK = 'click';
#   var AUX_CLICK = 'auxclick';
#
#   var defaultCallback = function defaultCallback() {
#     return addEventToDataLayer(payload);
#   };
#
#   if (element) {
#     element.addEventListener(CLICK, callback || defaultCallback);
#     element.addEventListener(AUX_CLICK, callback || defaultCallback);
#   }
# }
#                         function setEventsRoof() {
#   var roofs = document.querySelectorAll('[roof-container="roof-container"]') || [];
#   roofs.forEach(function (roof) {
#     var _getAnchorsFromGroup = getAnchorsFromGroup(roof),
#         anchorLeft = _getAnchorsFromGroup.anchorLeft,
#         actionLeft = _getAnchorsFromGroup.actionLeft,
#         anchorRight = _getAnchorsFromGroup.anchorRight,
#         actionRight = _getAnchorsFromGroup.actionRight;
#
#     var roofTitle = getRoofTitle(roof);
#
#     var addEventRoof = function addEventRoof(elem, type, title) {
#       var elemChildren = elem.target.children;
#       var description = elem.target.innerText || elem.target.alt || elemChildren[0] && (elemChildren[0].alt || elemChildren[0].innerHTML);
#       var payload = {
#         action: createDynamicLabel("caja_".concat(title || description)),
#         label: createDynamicLabel("".concat(type, "_").concat(description))
#       };
#       addEventToDataLayer(payload);
#     };
#
#     if (anchorLeft) {
#       addEventListeners(anchorLeft, null, function (elem) {
#         return addEventRoof(elem, actionLeft);
#       });
#     }
#
#     if (anchorRight) {
#       addEventListeners(anchorRight, null, function (elem) {
#         return addEventRoof(elem, actionRight, roofTitle);
#       });
#     }
#   });
# }
#                         function getAnchorsFromGroup(roof) {
#   var groupRight = roof.querySelector('[roof-group="right"]');
#   var groupLeft = roof.querySelector('[roof-group="left"]');
#   var anchorRight = groupRight && groupRight.lastChild;
#   var isAnchorLeft = groupLeft && groupLeft.tagName === 'A';
#   var isButtonLink = anchorRight && anchorRight.getAttribute && anchorRight.getAttribute('class').includes('button');
#   return {
#     anchorLeft: isAnchorLeft && groupLeft,
#     actionLeft: 'techo',
#     anchorRight: isButtonLink && anchorRight,
#     actionRight: 'cta'
#   };
# }
#                         function getRoofTitle(container) {
#   var logo = container.querySelector('.image');
#   var title = container.querySelector('.--roof-title');
#   return logo && logo.alt || title && title.innerText;
# }
#                         function setEventsRoof() {
#   var roofs = document.querySelectorAll('[roof-container="roof-container"]') || [];
#   roofs.forEach(function (roof) {
#     var _getAnchorsFromGroup = getAnchorsFromGroup(roof),
#         anchorLeft = _getAnchorsFromGroup.anchorLeft,
#         actionLeft = _getAnchorsFromGroup.actionLeft,
#         anchorRight = _getAnchorsFromGroup.anchorRight,
#         actionRight = _getAnchorsFromGroup.actionRight;
#
#     var roofTitle = getRoofTitle(roof);
#
#     var addEventRoof = function addEventRoof(elem, type, title) {
#       var elemChildren = elem.target.children;
#       var description = elem.target.innerText || elem.target.alt || elemChildren[0] && (elemChildren[0].alt || elemChildren[0].innerHTML);
#       var payload = {
#         action: createDynamicLabel("caja_".concat(title || description)),
#         label: createDynamicLabel("".concat(type, "_").concat(description))
#       };
#       addEventToDataLayer(payload);
#     };
#
#     if (anchorLeft) {
#       addEventListeners(anchorLeft, null, function (elem) {
#         return addEventRoof(elem, actionLeft);
#       });
#     }
#
#     if (anchorRight) {
#       addEventListeners(anchorRight, null, function (elem) {
#         return addEventRoof(elem, actionRight, roofTitle);
#       });
#     }
#   });
# }
#                         function setEventsNavigationLinks() {
#   var navigationLinks = document.querySelectorAll('[roof-group="right"] > .link.ln-link.flex');
#   navigationLinks.forEach(function (link) {
#     var roofTitle = getRoofTitle(link.parentNode.parentNode);
#     var payload = {
#       action: createDynamicLabel("caja_".concat(roofTitle)),
#       label: createDynamicLabel("tag_".concat(link.innerText))
#     };
#     addEventListeners(link, payload);
#   });
# }
#
#                         setEventsRoof()
#                         setEventsNavigationLinks()
#                     });
#                 </script><script type="text/javascript">
#                     window.addEventListener('DOMContentLoaded', () => {
#                         const articles = document.querySelectorAll('article');
#                         function isSandbox() {
#   if (window && window.location.host === 'lanacion.com.ar') return '';
#   return '_DESA';
# }
#                         function getName(element) {
#   var subtitle = element.querySelectorAll('h2, h1');
#
#   if (subtitle && subtitle.length > 0) {
#     return subtitle[0].innerText && subtitle[0].innerText.trim() || '';
#   }
#
#   return '';
# }
#                         function getDataSetProps(element) {
#   if (element) {
#     var _element$dataset = element.dataset,
#         articleDataSet = _element$dataset === void 0 ? {} : _element$dataset;
#
#     var _ref = element.closest && element.closest('[data-is-block]') || {
#       dataset: {
#         blockName: '',
#         diagramacionId: '',
#         chainPosition: '',
#         isSubscriptor: false
#       }
#     },
#         _ref$dataset = _ref.dataset,
#         chainDataSet = _ref$dataset === void 0 ? {} : _ref$dataset;
#
#     var _ref2 = element.closest && element.closest('[data-section]') || {
#       dataset: {
#         section: ''
#       }
#     },
#         _ref2$dataset = _ref2.dataset,
#         sectionDataSet = _ref2$dataset === void 0 ? {} : _ref2$dataset;
#
#     var chainPosition = chainDataSet.chainPosition,
#         diagramacionId = chainDataSet.diagramacionId,
#         blockName = chainDataSet.blockName,
#         isSubscriptor = chainDataSet.isSubscriptor;
#     var section = sectionDataSet.section;
#     var pos = articleDataSet.pos,
#         id = articleDataSet.id,
#         source = articleDataSet.source;
#     var itemBrand = isSubscriptor ? 'excSuscriptor' : section;
#     var product = {
#       position: "".concat(chainPosition || '').concat(pos),
#       id: id,
#       variant: source,
#       brand: "".concat(itemBrand, "_").concat(diagramacionId),
#       list: blockName,
#       name: getName(element)
#     };
#     var item = {
#       item_list_id: "".concat(chainPosition || '').concat(pos),
#       item_id: id,
#       item_variant: source,
#       item_brand: "".concat(itemBrand, "_").concat(diagramacionId),
#       item_list_name: blockName,
#       item_name: getName(element),
#       item_category: 'N/A',
#       price: 1,
#       index: 1,
#       quantity: 1
#     };
#     return {
#       product: product,
#       item: item
#     };
#   }
#
#   return {};
# }
#                         function productClickFromClient() {
#   var element = arguments.length > 0 && arguments[0] !== undefined ? arguments[0] : {};
#
#   var _getDataSetProps = getDataSetProps(element.currentTarget),
#       product = _getDataSetProps.product,
#       item = _getDataSetProps.item;
#
#   if (product.id) {
#     window.dataLayer.push({
#       event: "productClickScore",
#       product: product,
#       item: item
#     });
#   }
#
#   return true;
# }
#                         articles.forEach(art => {
#
#                             art.addEventListener('click', (element) => {
#                                 productClickFromClient(element);
#                             });
#
#                             art.addEventListener('auxclick', (element) => {
#                                 productClickFromClient(element);
#
#                             });
#
#                         })
#
#                     })
#                 </script></div><script id="fusion-metadata" type="application/javascript">window.Fusion=window.Fusion||{};Fusion.arcSite="la-nacion-ar";Fusion.contextPath="/pf";Fusion.deployment="1374";Fusion.globalContent={};Fusion.globalContentConfig={};Fusion.lastModified=1699025139788;Fusion.contentCache={"navigationTreeSource":{"{\"website\":\"la-nacion-ar\"}":{"data":{"_id":"/","Termicas":{"banners":"true","liftigniter":"true","livefyre":"true","mensaje_para_cierre_de_comentarios":"Por motivo de la veda electoral, los comentarios en el sitio estarán desactivados hasta las 18hs. del domingo 22 de Octubre. Muchas gracias.","bookmark":"true","bookmark_web":"true","weather":"true","dolar":"true","autoplay":"false","dolares":["dbna","dblue","dtarjeta","dturista","dmep","dccl","dmayorista","euro"],"paywall":"true","hide_listening_articles":"false","tooltip_text":"¡Últimas horas!</br>Precio fijo por 6 meses.","class_tooltip":"--top_l","button_text":"Suscribite por $249","sticky_button_text":"Suscribite por <del class=\"--mobile-none\">$2600</del> $249","buttonsuscribe":"false"},"site":{"site_url":"https://www.lanacion.com.ar/","with-amp":{"1":"nota-noticia","2":"nota-infografia","4":"nota-storytelling","5":"nota-video","6":"nota-liveblog","7":"nota-receta","8":"nota-foto-al-100","10":"nota-agencia"},"sitio_adserver":{"propiedades":"propiedades","campo":"campo","salud":"bienestar","autos":"movilidad","la_nacion_usa":"la_nacion_usa"},"tooltips":{"Análisis":"Interpretación de las noticias basada en evidencia, incluyendo datos y proyecciones posibles en base a eventos pasados.","Content LAB":"Content LAB es la unidad de generación de ideas y contenidos de LA NACION para las marcas con distribución en sus plataformas digitales y redes sociales. Este contenido fue producido para un anunciante y publicado por el Content LAB. La redacción de LA NACION no estuvo involucrada en la generación de este contenido.","Contribución de la audiencia":"Pedido de información a la audiencia.","Espacio Patrocinado":"Brindado por una organización o individuo que ha pagado al proveedor de noticias por este espacio.","Explicativo":"Provee contexto, definición y detalle de un tópico específico.","Noticia Original":"Información basada en hechos y verificada de primera mano por el cronista, o reportada y verificada por fuentes expertas.","Opinión":"Basada en la interpretación y juicio de hechos y datos realizados por el autor.","Review":"Crítica de un servicio, producto u obra creativa."},"script_loading_list":["{     \"id\": \"SWG-gaa-nota\",     \"async\": true,     \"location\": \"body-bottom\",     \"section\": \"nota\",     \"src\": \"https://news.google.com/swg/js/v1/swg-gaa.js\",     \"env\": \"prod\" }","{\"id\": \"SWG-news\", \"subscriptions-control\": \"manual\", \"location\": \"body-bottom\", \"section\": \"nota\", \"async\": true, \"src\": \"https://news.google.com/swg/js/v1/swg.js\", \"env\": \"prod\"}","{   \"id\": \"SWG-accounts\",   \"async\": true,   \"location\": \"body-bottom\",   \"section\": \"nota\",   \"src\": \"https://accounts.google.com/gsi/client\",   \"env\": \"prod\" }","{     \"id\": \"Gplatform\",     \"async\": true,     \"location\": \"body-bottom\",     \"section\": \"nota\",     \"src\": \"https://apis.google.com/js/platform.js\",     \"env\": \"prod\" }","{    \"id\": \"SwgClientLib\",   \"location\": \"body-bottom\",   \"section\": \"nota\",   \"defer\": true,   \"src\": \"https://static.glanacion.com/v2/registracionclientlibs/swgClientLibs-4.1.0-7b7fbed.js\",   \"crossorigin\": \"anonymous\",   \"Access-Control-Allow-Origin\": \"*.google.com\",   \"env\": \"prod\" }","{     \"id\": \"userClientLibs-home\",     \"location\": \"body-bottom\",     \"section\": \"home\",     \"async\": true,     \"src\": \"https://static.glanacion.com/v2/registracionclientlibs/userClientLibs-0.1.4-c1213c1.js\",     \"env\": \"prod\" }","{     \"id\": \"userClientLibs-acu\",     \"location\": \"body-bottom\",     \"section\": \"acumulado\", ...
#     window.addEventListener('load', () => {
#       const check = new Request(
#         'https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js',
#         { method: 'HEAD', mode: 'no-cors' }
#       );
#
#       fetch(check)
#         .then(() => dataLayer.push({
#           'event': 'adblock-detected',
#           'detectado': false
#         }))
#
#         .catch((err) => {
#           window.dataLayer = window.dataLayer || [];
#           window.dataLayer.push({
#             'event' : 'adblock-detected',
#             'detectado': true
#           });
#         });
#     });
#   </script><script async="" src="https://btloader.com/tag?o=5698152924446720&amp;upapi=true"></script><div defer="" type="text/javascript"><script id="marfeelScript">!function(){"use strict";function e(e){var t=!(arguments.length>1&&void 0!==arguments[1])||arguments[1],c=document.createElement("script");c.src=e,t?c.type="module":(c.async=!0,c.type="text/javascript",c.setAttribute("nomodule",""));var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(c,n)}!function(t,c){!function(t,c,n){var a,o,r;n.accountId=c,null!==(a=t.marfeel)&&void 0!==a||(t.marfeel={}),null!==(o=(r=t.marfeel).cmd)&&void 0!==o||(r.cmd=[]),t.marfeel.config=n;var i="https://sdk.mrf.io/statics";e("".concat(i,"/marfeel-sdk.js?id=").concat(c),!0),e("".concat(i,"/marfeel-sdk.es5.js?id=").concat(c),!1)}(t,c,arguments.length>2&&void 0!==arguments[2]?arguments[2]:{})}(window,3353 /* AccountId */,{} /* Config */)}();</script></div><script async="" env="prod" id="userClientLibs-home" src="https://static.glanacion.com/v2/registracionclientlibs/userClientLibs-0.1.4-c1213c1.js"></script><script defer="" type="text/javascript">window.addEventListener('DOMContentLoaded', (event) => {
#         document.querySelectorAll('.nacion-home').forEach(item => {
#             item.addEventListener('click', event => {
#                 sessionStorage.removeItem('hp');
#                 sessionStorage.removeItem('lb');
#             })
#           })
#     });</script></body></html>

# %% [markdown]
# Ahora todo lo que queda es encontrar los elementos que nos interese.
# ¿Cómo los identificamos? Es un trabajo de ida y vuelta, y prueba y error, así que a no frustrarse si no sale de entrada. Los pasos a seguir son:
# - Ir a la página que queremos scrapear y con el botón derecho del mouse poner "inspeccionar elemento" sobre el sector de la página que nos interese.
# - Luego podemos identificarlo por su *tag* o por algún atributo que nos permita identificarlo mejor, como por ejemplo, la clase (*class*).
# - A veces puede ser más conveniente no apuntarle al elemento que nos interesa sino a un nodo superior (que lo contenga) y a partir de ahí navegar hacia dentro.
#
# Investigando la página del diario La Nación encontramos que los recuadros correspondientes a los títulos y enlaces de las principales notas están dentro de bloques con atributo. Por ejemplo, algo del estilo:
# ~~~
# <... class = "com-title --xl">
# ~~~
# o
# ~~~
# <... class = "com-title --xs">
# ~~~
# (leer esta notebook a la par que de la inspección de la página. Las páginas se van actualizando y por lo tanto la forma del código HTML puede variar).
#
# Como observamos que el tag puede ser *h1* o *h2*, vamos a tratar de no especificar el *tag* para no perdernos nada. Buscamos entonces todos los elementos que cumplan con alguno de estos requisitos sin especificar el *tag*:

# %%
# Creamos una lista con los elementos cuya clase sea igual a lo que encontremos en la página, con cualquier tag
elements = soup.findAll(attrs = {"class": "description-container --relative flex flex-column"})

# %% [markdown]
# Vemos en qué consiste la lista de elementos:

# %%
len(elements)
# Out:
# 125

# %%
elements[2]
# Out:
# <section class="description-container --relative flex flex-column" href="/politica/presupuesto-2024-ganadores-y-perdedores-del-reparto-de-planes-sociales-que-proyecto-sergio-massa-nid03112023/"><h2 class="text ln-text title --prumo --font-medium --font-m-l"><span class="text ln-text lead --prumo --font-extra">Sin criterios objetivos.<!-- --> </span>Ganadores y perdedores del reparto de planes sociales que proyectó Massa para 2024</h2><div class="marquee-container flex ai-center" title="Por Gabriela Origlia"><div class="marquee-text flex flex-column --font-2xs w-100"><span class="text ln-text marquee">Por <strong>Gabriela Origlia</strong></span></div></div></section>

# %% [markdown]
# Veamos qué tenemos en algún elemento de ejemplo:

# %%
element = elements[0]

element
# Out:
# <section class="description-container --relative flex flex-column" href="/politica/fuerte-mensaje-de-juan-schiaretti-contra-sergio-massa-por-el-juicio-politico-a-la-corte-suprema-nid03112023/"><h1 class="text ln-text title --prumo --font-medium --font-4xl"><span class="text ln-text lead --prumo --font-extra">En defensa de la Corte.<!-- --> </span>Fuerte mensaje de Schiaretti: "El gobierno kirchnerista del ministro Sergio Massa"</h1><h2 class="text ln-text subhead --font-s">El gobernador cuestionó al oficialismo y pidió respetar la división de poderes; a poco más de dos semanas del balotaje, el candidato de Unión por la Patria se disputa con Milei los votos del mandatario cordobés </h2></section>

# %% [markdown]
# Vemos por ejemplo como sacar el texto aquí adentro y el enlace a la nota:

# %%
# Todo el texto contenido dentro del elemento
print(element.text)
# Out:
# En defensa de la Corte. Fuerte mensaje de Schiaretti: "El gobierno kirchnerista del ministro Sergio Massa"El gobernador cuestionó al oficialismo y pidió respetar la división de poderes; a poco más de dos semanas del balotaje, el candidato de Unión por la Patria se disputa con Milei los votos del mandatario cordobés

# %%
# Enlace a la nota (o parte del enlace, a veces es relativo a la página)
horacio-rodriguez-larreta-no-se-va-de-pro-y-se-escuda-en-el-polo-anti-milei-nid03112023/', '/economia/el-indice-de-inflacion-del-ministerio-de-economia-volvio-a-marcar-un-aumento-del-22-en-la-cuarta-nid03112023/', '/politica/postales-de-una-tarde-en-la-que-massa-y-milei-se-midieron-a-pocos-metros-de-distancia-nid03112023/', '/economia/campo/el-campo-no-pagara-la-fiesta-para-la-dirigencia-rural-massa-busca-aplicar-un-impuestazo-nid03112023/', '/politica/la-plata-una-periferia-degradada-detras-de-los-votos-bajo-la-lupa-nid02112023/', '/seguridad/en-retiro-esperan-la-autopsia-y-declaracion-de-la-esposa-para-esclarecer-la-muerte-del-turista-nid03112023/', '/seguridad/violacion-en-palermo-un-dia-despues-del-abuso-en-las-canitas-el-sospechoso-ataco-a-una-joven-en-un-nid03112023/', '/seguridad/inseguridad-vial-otro-tragico-accidente-costo-dos-vidas-en-la-llamada-ruta-de-la-muerte-nid02112023/', '/espectaculos/personajes/en-aeroparque-sofia-gala-fue-bajada-de-un-avion-acusada-de-no-haber-pagado-por-algunos-productos-en-nid03112023/', '/propiedades/construccion-y-diseno/construir-una-casa-en-un-country-bajaron-los-costos-pero-hay-un-factor-que-dificulta-aprovechar-la-nid01112023/', '/sociedad/el-sistema-de-salud-esta-roto-carta-abierta-de-un-medico-de-hospital-a-los-pacientes-y-sus-nid03112023/', '/deportes/salio-a-la-luz-el-gesto-que-lionel-messi-le-hizo-a-antonela-roccuzzo-desde-el-escenario-al-recibir-nid03112023/', '/sociedad/secretos-del-conurbano-el-legado-britanico-donde-descansan-caidos-en-las-guerras-mundiales-y-el-nid03112023/', '/propiedades/casas-y-departamentos/miami-inauguran-500-departamentos-economicos-y-planean-construir-mas-de-30000-nid02112023/', '/sociedad/desc ...

# %%
print(len(urls))
# Out:
# 125

# %% [markdown]
# Ya tenemos enlaces de páginas (¿son todos los que vemos cuando abrimos la página? ¿No habrá contenido dinámico que nos estamos perdiendo?).

# %% [markdown]
# ### Scrappeo de la página de un artículo

# %% [markdown]
# Veamos si podemos extraer contenido de las notas cuyos enlaces extraímos. La idea es la misma: ir a la página e inspeccionar los elementos que nos interese. Cuando las páginas corresponden a la misma plataforma es usual que la información se encuentre en el mismo lugar, por lo que aprendamos de una sola paǵina podemos quizás extrapolarlo a otras.
#
# Agarremos un *url* (por ejemplo, alguno de los de arriba) y generemos la sopa:

# %%
# Url de interés
url = 'https://www.lanacion.com.ar/el-mundo/israel-entre-la-tension-por-un-posible-nuevo-frente-con-hezbollah-el-cerco-sobre-la-ciudad-de-gaza-y-nid03112023/'

# Hacemos un request a dicha página
response = requests.get(url)
print(response.status_code)

# Creamos la sopa para manipular
soup = BS(response.content)
# Out:
# 200

# %% [markdown]
# Identificando dónde está el título de la nota (eso de vuelta, inspeccionando el elemento asociado), podemos extraer el texto.
# Es posible que haya muchas formas de encontrar un mismo elemento, basta con ser lo más preciso posible para obtener la información que querramos, pero lo suficientemente general para que sea extrapolable a todas las páginas.

# %%
# Buscamos el elemento cuya clase indentificamos como correspondiente al título de la nota
title = soup.find(attrs = {"class": "com-title --font-primary --sixxl --font-extra"}) # Funcionó sólo con el nombre del tag, pero podríamos haber especificado los atributos de clase(attrs = {"class": "com-title --threexl"})
print(title.text)
# Out:
# El líder de Hezbollah dice que el ataque de Hamas fue “100% palestino”, pero advierte sobre una posible guerra regional: “Todas las opciones están sobre la mesa”

# %% [markdown]
# Fecha de la nota (de nuevo, inspeccionar la página hasta dar en la tecla de dónde está esta información):

# %%
date = soup.find(attrs = {"class": "com-date --twoxs"})
print(date.text)
# Out:
# 3 de noviembre de 2023

# %% [markdown]
# O, urgando un poco más en el código HTML, podemos extraer la fecha mejor formateada (notar otra manera de buscar cosas con BS):

# %%
# Buscamos un tag del tipo "meta", cuyo atributo "property" tiene valor "article:published_time"
# A este tag le sacamos el valor que toma el atributo "content"
datetime = soup.find("meta", attrs = {"property": "article:published_time"})['content']
print(datetime)
# Out:
# 2023-11-03T15:15:43.952Z

# %% [markdown]
# Veamos la descripción de la nota, que podemos encontrarla en:

# %%
description = soup.find(attrs = {"class": "com-subhead --bajada --m-xs-"})
print(description.text)
# Out:
# Hassan Nasrallah brindó un extenso discurso por primera vez desde que estalló el conflicto y apuntó contra Estados Unidos mientras Antony Blinken está en Tel Aviv para pedir una pausa en la ofensiva israelí

# %% [markdown]
# Por último veamos el cuerpo de la nota. Encontramos un nodo padre del tipo *section* cuya clase es *cuerpo__nota* (notar que tenemos que escribir todo exactamente como lo vemos en el código de la página. Cualquier error de tipeo va a resultar en que no nos devuelva nada):

# %%
# Buscamos un tag del tipo "section", cuyo atributo "class" tiene valor "cuerpo__nota"
body = soup.find("section", attrs = {"class": "cuerpo__nota"})

# %% [markdown]
# Usualmente, los párrafos están dentro de tags denominados *p*. Por lo que buscamos todos estos dentro del bloque asociado al cuerpo de la nota:

# %%
# Párrafos usualmente dentro de tags p
paragraphs = body.findAll('p')

print(paragraphs)
# Out:
# [<p class="com-paragraph --capital --s">KHAN YOUNIS, Franja de Gaza.- El líder de Hezbollah,<strong> Hassan Nasrallah</strong>, sorprendió hoy con un enérgico discurso en el que<strong> subrayó que “todas las opciones están sobre la mesa” </strong>en el marco de <a class="com-link" data-reactroot="" href="https://www.lanacion.com.ar/el-mundo/guerra-en-medio-oriente-israel-combate-en-dos-frentes-y-empieza-a-sentir-la-feroz-resistencia-de-nid02112023/" target="_self" title="la guerra en Gaza">la guerra en Gaza</a>, avivando el temor a que el conflicto se extienda a la región, al tiempo que <strong>acusó a Estados Unidos de ser responsable de los “crímenes perpetrados por Israel</strong>”.</p>, <p class="com-paragraph --s">En una aparición televisada de casi una hora y media, Nasrallah elogió en repetidas ocasiones la sanguinaria ofensiva perpetrada por Hamas el 7 de octubre, una operación que, según sus palabras, fue<strong> “decidida e implementada al 100% por palestinos”. </strong>Fue su primer mensaje público desde que comenzó la guerra.</p>, <p dir="ltr" lang="en">🔴 “LIVE: Sayyed Hassan Nasrallah, the Secretary General of Lebanon’s Hezbollah resistance movement, delivers speech <a href="https://t.co/jr84oCDLZz">https://t.co/jr84oCDLZz</a></p>, <p class="com-paragraph --s">En este sentido, Nasrallah afirmó que lo sucedido confirma que <strong>“Irán no ejerce ninguna tutela sobre las facciones de resistencia</strong>”.</p>, <p class="com-paragraph --s">Nasrallah sostuvo durante su discurso que la ofensiva de Hamas “ha expuesto las debilidades de Israel”. <strong>“Los israelíes piensan ahora, incluso más que yo, que Israel es más débil que una tela de araña”</strong>, argumentó, al tiempo que destacó que <strong>“la operación allana el camino para una nueva era en la región”</strong>.</p>, <p class="com-paragraph --s">También apuntó que <strong>el peor error de Israel ahora es establecer objetivos inalcanzables</strong>, en alusión a la contraofensiva y a su intento de “destruir” a Hamas.</p>, <p class="com-paragraph --s">Por su parte, el líder de Hezbollah estableció <strong>dos objetivos propios de cara al conflicto: el primero, detener la guerra en Gaza y, el segundo, que Hamas salga victorioso</strong>.</p>, <p class="com-paragraph --s">Aunque no dio precisiones sobre los próximos pasos, dijo que <strong>“todas las opciones están sobre la mesa”</strong> e <strong>instó a los países árabes y musulmanes a trabajar juntos para detener la guerra. “Todos debemos estar listos y presentes para cualquier posibilidad y cualquier asunción en el futuro”</strong>, zanjó.</p>, <p class="com-paragraph --s">Nasrallah dijo que su grupo había “entrado en la batalla” con los combates transfronterizos sin precedentes de las últimas semanas y advirtió sobre una posible escalada: <strong>“No nos limitaremos a esto”.</strong></p>, <p class="com-paragraph --s">Desde el 8 de octubre, según Nasrallah, Hezbollah ha intensificado sus operaciones día a día, obligando a Israel a mantener sus fuerzas cerca de la frontera libanesa en lugar de Gaza o la Cisjordania ocupada. Estos intercambios han resultado en <strong>la muerte de</strong> <strong>57 combatientes </strong>de la organización musulmana libanesa, confirmó el líder.</p>, <p class="com-paragraph --s">Por ello, indicó que “desde el 8 de octubre, la resistencia islámica ha estado participando en una batalla real que sólo los que están presentes en la frontera pueden sentir” y sostuvo que estos acontecimientos “no habían tenido lugar desde 1948 –año de la creación del Estado de Israel–, incluso en la Guerra de Julio –en referencia al conflicto de 2006–, cuando todas las instalaciones del enemigo fueron objetivo de operaciones ofensivas”.</p>, <p class="com-paragraph --s">“Estas operaciones en la frontera han creado un estado de ansiedad, pánico y miedo en la cúpula enemiga y entre los estadounidenses ante la posibilidad de que el frente derive en un recrudecimiento adicional o en que provoque <str ...

# %%
paragraphs[0].text
# Out:
# 'KHAN YOUNIS, Franja de Gaza.- El líder de Hezbollah, Hassan Nasrallah, sorprendió hoy con un enérgico discurso en el que subrayó que “todas las opciones están sobre la mesa” en el marco de la guerra en Gaza, avivando el temor a que el conflicto se extienda a la región, al tiempo que acusó a Estados Unidos de ser responsable de los “crímenes perpetrados por Israel”.'

# %%
# Iteramos para todo párrafo y vemos el texto contenido
# Podemos hacer una lista y concatenar todo con un salto de línea
texts = []
for p in paragraphs:
  texts.append(p.text)

body_text = '\n'.join(texts)

print(body_text)
# Out:
# KHAN YOUNIS, Franja de Gaza.- El líder de Hezbollah, Hassan Nasrallah, sorprendió hoy con un enérgico discurso en el que subrayó que “todas las opciones están sobre la mesa” en el marco de la guerra en Gaza, avivando el temor a que el conflicto se extienda a la región, al tiempo que acusó a Estados Unidos de ser responsable de los “crímenes perpetrados por Israel”.
# Israel expidió anteriormente más de 18.000 permisos que permitían a los gazatíes cruzar a Israel y a Cisjordania, para ocupar puestos de trabajo en sectores como la agricultura o la construcción, que normalmente conllevaban salarios hasta 10 veces superiores a lo que un trabajador podía ganar en la bloqueada Franja de Gaza.
# Sin embargo, el sistema se ha desechado, ya que Israel ha dado marcha atrás en su política anterior de ofrecer incentivos económicos a la estabilidad y, en su lugar, ha montado una ofensiva combinada de aire y tierra para erradicar el movimiento militante Hamás que controla Gaza.
# “Israel está cortando todo contacto con Gaza. No habrá más trabajadores palestinos de Gaza”, dijo la oficina del primer ministro Netanyahu en un comunicado. “Los trabajadores de Gaza que estaban en Israel el día del estallido de la guerra serán devueltos a Gaza”.
# Un alto funcionario de la Autoridad Palestina declaró que 4950 residentes de Gaza habían huido a Cisjordania desde Israel y que se creía que unos 5000 habían sido detenidos por Israel.
# “Nadie sabe lo que está pasando”, declaró Ghazal Ghazal, de 50 años, que trabajaba en una fábrica de dulces en Tel Aviv antes de huir a Cisjordania el mes pasado, tras enterarse por sus compañeros de que las autoridades israelíes estaban llevando a cabo detenciones.
# Agencias AP y Reuters

# %% [markdown]
# Si vemos que falta parte del texto, tenemos que identificar dónde le erramos: puede ser que el texto no esté dentro del párrafo, por lo que tendríamos que ver qué tag tiene asociado, con qué clase o atributo que nos permita acceder.

# %% [markdown]
# ### Iteración sobre varios urls
#
# Una de las cosas interesantes del scrapeo es poder iterar sobre varias páginas y extraer información en forma sistemática. Extraigamos el título y la descripción para un conjunto de urls. Básicamente es hacer lo que hicimos para una nota varias veces:

# %%
# Recordamos teníamos un listado de urls
urls
# Out:
# ['/politica/fuerte-mensaje-de-juan-schiaretti-contra-sergio-massa-por-el-juicio-politico-a-la-corte-suprema-nid03112023/',
#  '/el-mundo/israel-entre-la-tension-por-un-posible-nuevo-frente-con-hezbollah-el-cerco-sobre-la-ciudad-de-gaza-y-nid03112023/',
#  '/politica/presupuesto-2024-ganadores-y-perdedores-del-reparto-de-planes-sociales-que-proyecto-sergio-massa-nid03112023/',
#  '/tecnologia/un-yacimiento-de-hidrogeno-blanco-podria-disparar-una-revolucion-energetica-nid02112023/',
#  '/economia/la-caida-de-ingresos-llegaria-al-14-este-ano-el-mayor-descenso-en-20-anos-nid03112023/',
#  '/deportes/salio-a-la-luz-el-gesto-que-lionel-messi-le-hizo-a-antonela-roccuzzo-desde-el-escenario-al-recibir-nid03112023/',
#  '/el-mundo/israel-entre-la-tension-por-un-posible-nuevo-frente-con-hezbollah-el-cerco-sobre-la-ciudad-de-gaza-y-nid03112023/',
#  '/economia/dolar/dolar-hoy-dolar-blue-hoy-a-cuanto-cotiza-este-viernes-3-de-noviembre-nid03112023/',
#  '/el-mundo/tras-su-operacion-de-cadera-lula-se-mostro-ejercitando-en-breve-vuelta-a-las-canchas-nid03112023/',
#  '/sociedad/es-sobrina-chozna-de-camila-ogorman-cuenta-la-otra-cara-de-su-historia-y-quiere-restaurar-la-boveda-nid02112023/',
#  '/lifestyle/utopia-libertaria-viaje-al-pueblo-estadounidense-donde-se-aplico-el-experimento-anarcocapitalista-de-nid03112023/',
#  'https://www.lanacion.com.ar/propiedades/casas-y-departamentos/desde-us50000-un-departamento-la-zona-a-cinco-minutos-de-la-ciudad-que-crece-con-proyectos-premium-y-nid31102023/',
#  'https://www.lanacion.com.ar/propiedades/inmuebles-comerciales/reabrio-osaka-el-restaurante-top-apuesta-por-la-reconversion-de-una-zona-con-alta-gastronomia-y-nid01112023/',
#  'https://www.lanacion.com.ar/economia/campo/practicamente-de-rodillas-un-diputado-de-jxc-le-hizo-un-fuerte-reclamo-al-gobierno-de-kicillof-por-nid01112023/',
#  'https://www.lanacion.com.ar/economia/campo/frontera-roja-el-impactante-video-que-muestra-como-se-contrabandea-carne-a-paraguay-nid01112023/',
#  'https://www.lanacion.com.ar/economia/campo/ganaderia/entre-la-carne-y-la-sustentabilidad-los-desafios-de-la-ganaderia-nid02112023/',
#  'https://www.lanacion.com.ar/economia/campo/a-la-mier-a-dias-de-la-cosecha-el-granizo-arraso-en-una-region-agricola-nid30102023/',
#  'https://www.lanacion.com.ar/lifestyle/como-afrontar-los-duelos-la-medicacion-no-anestesia-el-proceso-sino-que-permite-atravesarlo-de-nid03112023/',
#  'https://www.lanacion.com.ar/lifestyle/los-paises-mas-visitados-las-10-ciudades-del-mundo-mas-elegidas-a-la-hora-de-salir-de-vacaciones-en-nid02112023/',
#  'https://www.lanacion.com.ar/lifestyle/estudiar-siempre-4-propuestas-para-capacitarse-nid03112023/',
#  'https://www.lanacion.com.ar/revista-jardin/que-hacer-para-tener-mas-y-mejor-fruta-esta-temporada-nid03112023/',
#  'https://www.lanacion.com.ar/revista-lugares/rio-de-janeiro-15-paseos-imperdibles-para-reenamorarse-de-la-cidade-maravilhosa-nid03112023/',
#  'https://www.lanacion.com.ar/economia/cuando-cobro-potenciar-trabajo-en-noviembre-y-de-cuanto-es-el-monto-con-el-bono-nid03112023/',
#  'https://www.lanacion.com.ar/economia/como-pedir-el-credito-de-600000-para-jubilados-de-anses-nid02112023/',
#  'https://www.lanacion.com.ar/lifestyle/como-tramitar-la-ciudadania-espanola-nid02112023/',
#  'https://www.lanacion.com.ar/economia/por-que-no-hay-bancos-este-lunes-6-de-noviembre-nid01112023/']

# %%
# Barremos en el listado de urls
# Le ponemos un try-except para ignorar errores
for url in urls_complete:

  try:

    # Hacemos request al url actual
    response = requests.get(url)

    # Creamos la sopa
    soup = BS(response.content)

    # Identificamos el título
    title = soup.find(attrs = {"class": "com-title --font-primary --sixxl --font-extra"}).text

    # Identificamos la descripción
    description = soup.find(attrs = {"class": "com-subhead --bajada --m-xs-"}).text

    # Printeamos ambas y dejamos un espacio entre nota y nota
    print(title)
    print(description)
    print('\n\n')

  except:
    pass
# Out:
# Fuerte mensaje de Juan Schiaretti contra Sergio Massa por el juicio político a la Corte Suprema
# El gobernador cuestionó al oficialismo y pidió respetar la división de poderes; a poco más de dos semanas del balotaje, el candidato de Unión por la Patria se disputa con Milei los votos del mandatario cordobés
#
#
#
# El líder de Hezbollah dice que el ataque de Hamas fue “100% palestino”, pero advierte sobre una posible guerra regional: “Todas las opciones están sobre la mesa”
# Hassan Nasrallah brindó un extenso discurso por primera vez desde que estalló el conflicto y apuntó contra Estados Unidos mientras Antony Blinken está en Tel Aviv para pedir una pausa en la ofensiva israelí
#
#
#
# Presupuesto 2024 | Ganadores y perdedores del reparto de planes sociales que proyectó Sergio Massa para 2024
# Jujuy, Chaco, Tucumán y la provincia de Buenos Aires son las provincias más favorecidas con el plan Potenciar Trabajo, según lo proyectado por el ministro-candidato
#
#
#
# Un yacimiento de hidrógeno blanco “casi infinito” podría disparar una revolución energética
# Dos científicos franceses hallaron en la región de Lorena, en el noroeste francés, un gigantesco yacimiento de  hidrógeno blanco (es decir, que no está combinado con otros elementos y no requiere tratamiento para ser usado como combustible) que equivaldría a la mitad de la producción mundial, y que podría regenerarse
#
#
#
# La caída de ingresos llegaría al 14% este año, el mayor descenso en 20 años
# La masa de recursos percibidos por trabajadores, jubilados y beneficiarios de planes sociales medida en términos reales vuelve a niveles de 2007, alertó un informe privado
#
#
#
# Salió a la luz el gesto que Lionel Messi le hizo a Antonela Roccuzzo desde el escenario al recibir el Balón de Oro
# Luego de recibir el premio y rodeado de sus hijos, el capitán argentino no se olvidó de su esposa y tuvo una gran reacción
#
#
#
# El líder de Hezbollah dice que el ataque de Hamas fue “100% palestino”, pero advierte sobre una posible guerra regional: “Todas las opciones están sobre la mesa”
# Hassan Nasrallah brindó un extenso discurso por primera vez desde que estalló el conflicto y apuntó contra Estados Unidos mientras Antony Blinken está en Tel Aviv para pedir una pausa en la ofensiva israelí
#
#
#
# Dólar hoy, dólar blue hoy: a cuánto cotiza este viernes 3 de noviembre
# La divisa estadounidense paralela se negocia a $915 para la venta; en tanto, el oficial se vende a $365,50
#
#
#
# Tras su operación de cadera, Lula se mostró ejercitando: “En breve, vuelta a las canchas”
# El presidente de Brasil fue intervenido en septiembre pasado por una artrosis que le causaba mucho dolor y le imposibilitaba moverse
#
#
#
# Es sobrina chozna de Camila O’Gorman, cuenta la otra cara de su historia y quiere restaurar la bóveda del cementerio de la Recoleta
# Pilar es descendiente de una de las mujeres más conocidas de la historia argentina; en diálogo con LA NACION, habla de aquella joven que, en 1848, fue ejecutada por vivir un amor prohibido; "
#
#
#
# Utopía libertaria. Viaje al pueblo estadounidense donde se aplicó el experimento anarcocapitalista de la libertad “total”
# Grafton está ubicado en New Hampshire, Estados Unidos; en 2004, alrededor de 200 militantes libertarios se mudaron allí, ante la desafiante reticencia de la población local
#
#
#
# Fintech: el sector que revolucionó las finanzas de los argentinos cada año recibe menos inversiones
# De acuerdo con el informe Finnovista Fintech Radar Argentina 2023, las inversiones en el sector cayeron un 95,7% en el último año; sin embargo, las aplicaciones de gestión de patrimonio se convirtieron en líderes de la región
#
#
#
# Boca Juniors hoy, en vivo: todo sobre la final de la Copa Libertadores ante Fluminense
# El minuto a minuto de lo que sucede en la previa del partido decisivo
#
#
#
# El boliche rutero que hace 200 sándwiches en una mañana y es parada obligada desde 1981
# La familia propietaria de la estación de servicio de Piedra del Águila, donde está el local, se hizo cargo también de la cocina; los secretos del crudo y queso más codiciado
#
#
#
# Rumbo a Río: la ruta poco explorada por los hinchas de Boca para llegar a la final de la Copa Libertadores
# Algunos seguidores del Xeneize encontraron un camino alternativo para atravesar la frontera rumbo a Río de Janeiro
#
#
#
# Valentín Barco, el 10 de Boca: con rebeldía y gambetas, el abanderado de Almirón para ganar la Copa Libertadores es un “chico” de 19 años
# No tiene un remate potente, pero lo suplanta con técnica, se desdobla y llega a pisar el área rival y, por sus gambetas, es uno de los jugadores al que más infracciones le cometen
#
#
#
# La travesía de la primera familia de hinchas de Boca en llegar al Sambódromo de Río
# Los Dotto son de Berazategui, se juntaron en Entre Ríos y salieron en un periplo con una humilde casa rodante
#
#
#
# Boca vs. Fluminense: una final de Copa Libertadores en Río de Janeiro que da miedo por la violencia previa
# La “emboscada” de los hinchas tricolores, la violenta acción policial, la llegada de más argentinos y el “banderazo” de este viernes; Conmebol emitió un comunicado para llamar a la paz
#
#
#
# Pese al desaire de Macri, Horacio Rodríguez Larreta no se va de Pro y se escuda en el polo anti Milei para resistir después del balotaje
# Tras la ruptura con el expresidente, estrecha lazos con la UCR, Carrió, Pichetto y Schiaretti para armar un bloque opositor a Massa o a los libertarios
#
#
#
# El índice de inflación del Ministerio de Economía volvió a marcar un aumento del 2,2% en la cuarta semana de octubre
# El viceministro Gabriel Rubinstein reconoció que el alza sostenida de los precios “sigue siendo muy alta” y la atribuyó a un “contexto de actualizaciones de algunos rubros”
#
#
#
# Postales de una tarde en la que Massa y Milei se midieron a pocos metros de distancia
# La Asamblea Legislativa para oficializar a los candidatos del balotaje dejó imágenes de alto voltaje, con los grandes protagonistas de este momento histórico
#
#
#
# “El campo no pagará la fiesta”: para la dirigencia rural, Massa busca aplicar un “impuestazo”
# La Mesa de Enlace pidió al Congreso no avalar la mayor carga impositiva que implicaría, entre otras cosas, una quita de la exención de las tierras rurales en Bienes Personales; fuerte reacción de Carbap
#
#
#
# En Retiro: esperan la autopsia y declaración de la esposa para esclarecer la muerte del turista francés en una comisaría
# La víctima,  Andrés René Mateier, tenía 77 años y estaba por viajar con su esposa a las Cataratas del Iguazú
#
#
#
# Violación en Palermo: un día después del abuso en Las Cañitas, el sospechoso atacó a una joven en un tren
# Según la denuncia de la víctima, la agresión ocurrió en una formación del ferrocarril Belgrano Norte que se dirigía sentido a la estación Villa Rosa; 24 horas antes de ser detenido, el sospechoso había protagonizado incidentes en la estación Grand Bourg
#
#
#
# Inseguridad vial. Otro trágico accidente costó dos vidas en la llamada “ruta de la muerte”
# Un hombre y un menor fallecieron y tres mujeres resultaron heridas cuando se perdió el control de un vehículo en los alrededores de Rafaela
#
#
#
# Confuso episodio en Aeroparque: Sofía Gala fue demorada por PSA y debió bajar del avión en el que iba a viajar a Mar del Plata
# El jueves por la tarde la actriz debió abandonar el vuelo 1608 de Aerolíneas Argentinas, programado para el mediodía,  señalada de no haber pagado por ciertos productos en el free shop; “Es tan ridículo que no se puede hablar. No sé qué pasó”, dijo ella
#
#
#
# Bajó el costo, en dólares, de construir una casa en un country
# Los costos de construcción se encuentran en su punto más bajo desde la pandemia y los countries están viviendo un boom de obras, pero la incertidumbre política genera inquietudes; lo que hay que saber
#
#
#
# “El sistema de salud está roto”. Carta abierta de un médico de hospital a los pacientes y sus familiares
# Mauro Brangold ejerce desde hace 40 años y decidió escribir sobre una crisis sanitaria terminal que sigue ausente en la campaña electoral y el interés colectivo
#
#
#
# Salió a la luz el gesto que Lionel Messi le hizo a Antonela Roccuzzo desde el escenario al recibir el Balón de Oro
# Luego de recibir el premio y rodeado de sus hijos, el capitán argentino no se olvidó de su esposa y tuvo una gran reacción
#
#
#
# Miami: inauguran 500 departamentos económicos y planean construir más de 30.000
# Se inauguraron dos torres, una reciclada de 315 departamentos y otra nueva de siete pisos con 182 unidades; quiénes pueden acceder a una de las viviendas
#
#
#
# Descubrieron que los agujeros negros funcionan como las fuentes de agua
# Científicos japoneses determinaron que reciclan gas como lo hacen esos artefactos al expulsar y recibir el líquido; es un hecho importante porque aún no se sabía sobre los procesos que se dan en esos cuerpos
#
#
#
# Es sobrina chozna de Camila O’Gorman, cuenta la otra cara de su historia y quiere restaurar la bóveda del cementerio de la Recoleta
# Pilar es descendiente de una de las mujeres más conocidas de la historia argentina; en diálogo con LA NACION, habla de aquella joven que, en 1848, fue ejecutada por vivir un amor prohibido; "
#
#
#
# La serie recomendada de Netflix para maratonear este noviembre con lluvia
# Se trata de un drama romántico estadounidense de cuatro capítulos ambientado en Francia durante la Segunda Guerra Mundial y cuenta con el director de Stranger Things y el guionista de Peaky Blinders
#
#
#
# Autos usados: qué modelos se consiguen por $4 millones en noviembre
# Los valores en el mercado de usados siguen en aumento pero todavía quedan opciones en este rango; cuáles son
#
#
#
# “Enfermedad silente”: cómo detectar el cáncer más frecuente en varones que, en sus inicios, no genera síntomas
# En el país, se estima que la enfermedad afecta a uno de cada siete varones; los expertos recomiendan realizarse controles preventivos
#
#
#
# Puertas adentro. Un paseo por L’Auberge, ícono arquitectónico entrañable y sinónimo de los waffles más ricos de Punta del Este
# Obra del arquitecto argentino Arturo Dubourg la famosa “Torre de los waffles”, como se conoce popularmente al hotel L’Auberge, es un clásico del panorama esteño desde hace 75 años. Los llevamos a conocer su pasado y su presente.
#
#
#
# El jefe de las Fuerzas Armadas de Ucrania admite que el frente de guerra con Rusia está estancado
# Valeri Zaluzhni, prevé que no haya avances al menos en un año y compara la situación con la Primera Guerra Mundial, en la que ambos bandos luchaban durante meses por unos pocos metros
#
#
#
# Matarán y esterilizarán a varios de los hipopótamos de Pablo Escobar, convertidos en plaga en Colombia
# En los años 80 el máximo narcotraficante introdujo una pareja de animales en su zoológico personal, y hoy ya suman 166 ejemplares que provocan graves daños en el ecosistema
#
#
#
# Las impactantes imágenes de la tormenta que azotó a Europa y dejó al menos siete muertos
# El fenómeno afectó ciudades de Francia, Países Bajos, España e Inglaterra; las ráfagas de viento superaron los 200 km por hora y más de un millón de hogares se quedaron sin suministro eléctrico
#
#
#
# Guerra en Medio Oriente: el kibutz Be’eri, la comuna agrícola donde una familia israelí creyó estar a salvo de Hamas
# “Pensábamos que aquí estábamos seguros y éramos fuertes. Pero después de que esto sucedió, espero que alguien despierte y comience otra estrategia”, alegó Gilad Korngold, cuya familia fue tomada como rehén el pasado 7 de octubre
#
#
#
# Tras reunirse con Biden, Boric rechaza ser “obligado a elegir entre uno y otro bando” en la guerra de Israel y Hamas
# En Washington, el presidente chileno condenó tanto los atentados terroristas como los operativos militares en la Franja de Gaza; dijo que la situación en el enclave palestino es “sencillamente inaceptable”
#
#
#
# Juegos Panamericanos Santiago 2023: el canotaje cosechó tres medallas en 60 minutos y la ‘abuela’ agigantó su historia
# La primera jornada de finales se realizó este viernes en la Laguna Grande San Pedro de la Paz
#
#
#
# Juegos Panamericanos: los secretos de la cocina en la que comen los atletas de la Villa de Santiago 2023
# El chef a cargo devela cuánta comida preparan y qué se consume más
#
#
#
# El campo tuvo la lluvia más importante de la primavera y acelerará una siembra donde busca revancha
# En la pampa húmeda se registraron precipitaciones de buena cobertura y caudal; frenan pérdidas en trigo, ayudan al maíz implantado y permiten avanzar con la soja; expectativa por una mejor campaña tras la sequía
#
#
#
# LiBooks: cinco libros que llegan en noviembre y que no podés perderte
# Te compartimos las mejores novedades que llegan este mes a LiBooks, la librería del diario LA NACION
#
#
#
# “De un extremo a otro”: desesperada evacuación de hacienda donde antes asolaba la sequía
# En el litoral la crecida del río Paraná y el avance de la inundación en los campos costeros obliga al traslado del ganado
#
#
#
# Para propietarios e inquilinos: cómo son los créditos para refacciones del hogar que se pagan en pesos
# Abrió la inscripción para el programa de créditos Buenos Aires Crea para hacer reformas, remodelaciones o ampliaciones del hogar para propietarios e inquilinos en Provincia de Buenos Aires
#
#
#
# Todo en uno: Elon Musk quiere hacer de X una app de citas para competir con Tinder
# El dueño de X declaró que está en desarrollo una nueva función que permitirá a las personas buscar pareja dentro de la plataforma
#
#
#
# El tremendo cruce cara a cara entre Lourdes Sánchez y Flor Vigna en los pasillos de América: “Sacate la careta”
# Las cámaras de LAM fueron las que registraron el momento exacto en el que las bailarinas se cruzaron y no se guardaron nada
#
#
#
# ¿Querés un ascenso en el trabajo? Seguí estos seis consejos basados en la ciencia
# La falta de un entorno que permita el crecimiento profesional es la cuarta razón más común de renuncia
#
#
#
# Confusa situación en América: por qué no se emite Intratables y la razón por la que Marcela Tinayre dejará de competir con su hija Juana
# Este domingo el ciclo no saldrá al aire por tercera semana consecutiva; por un tema presupuestario, todos los programas del canal salen desde un único estudio
#
#
#
# Aunque tenía pasaje comprado y casi se queda, cuenta lo que nadie dice del momento previo a irte del país: “Tuve ataques de ansiedad”
# Se fue a vivir a Andorra con las ganas de iniciar un recorrido por distintos países del mundo, pero el plan de vida nómade estuvo a punto de colapsar antes de empezar.
#
#
#
# Boris Karloff presenta: cómo la mejor serie de terror de la historia de la TV no pudo con la “mano negra” de Alfred Hitchcock
# Teniendo de anfitrión al actor más identificado con el monstruo de Frankenstein, esta serie llenó la TV de los sesenta con el terror más brutal y sofisticado que se hubiera visto hasta el momento, pero, pese a que se impuso en el gusto popular, terminó cancelada por pedido de director británico
#
#
#
# Lo rechazaba, algo cambió y vivió un amor que atravesó dos bodas canceladas y una gran batalla: “Pedía llegar a los 15 de mi hija”
# Cuando lo conoció no le interesaba, años después se reencontraron y entre ellos comenzó una historia que atravesó caminos impensados
#
#
#
# María Becerra dejó sin palabras a un periodista al contarle qué hace antes de sus shows: “¡Quiero uno!”
# La cantante de 23 años estuvo en el reconocido programa español “El Hormiguero”; reveló cómo es su minuto a minuto antes de salir al escenario
#
#
#
# “Somos muy mansos”: quejas y mea culpa de los productores en una movilización por la falta de gasoil
# En San Antonio de Areco, en una jornada de protesta hubo fuertes críticas por la escasez del combustible y la situación general del sector debido a las políticas del Gobierno
#
#
#
# “Justicia tributaria”: Massa le puso la lupa a los campos de argentinos en el exterior
# El ministro de Economía y candidato presidencial cuestionó en ese caso una exención vigente para las tierras rurales en el impuesto a los Bienes Personales y sugirió que, después de las elecciones, el Congreso debería avanzar en una discusión del tema
#
#
#
# Denuncian que una medida gremial bloqueó exportaciones pesqueras por US$10 millones
# La Cámara de Armadores de Pesqueros y Congeladores de la Argentina (Capeca) señaló que una acción del sindicato de estibadores impidió la carga de contenedores
#
#
#
# “Nunca se vio tan grande”: se perdieron 1,4 millones de kilos de frutillas por un devastador granizo
# El fin de semana pasado una tormenta causó estragos en la zona de Coronda, Santa Fe, dañando aproximadamente 170 hectáreas
#
#
#
# Los desafíos cruciales que enfrentan los candidatos
# El debate, el rol de los nuevos y viejos aliados, el reparto de cargos y el anclaje territorial para lograr una victoria el 19 de noviembre aparecen como elementos demasiado alejados del control de Massa y Milei
#
#
#
# La Argentina, un país de puras inconsistencias
# Los empresarios se han acostumbrado ya a esta economía en la que es evidente a esta algura que no hay dólares para nadie; pero no solo en el mercado de cambio hay problemas
#
#
#
# El sistema de salud, en crisis (Parte I)
# Los argentinos venimos padeciendo las consecuencias de muchos años de políticas erróneas y de brutal demagogia en materia sanitaria
#
#
#
# ¿Massa o Milei? La disyuntiva de 9 millones de votantes que definirán el balotaje
# Los dos candidatos presidenciales buscan correrse hacia el centro, conscientes de que podría ganar quien provoque menos miedo en el electorado no alineado detrás de ninguno de ellos
#
#
#
# Salió a la luz el gesto que Lionel Messi le hizo a Antonela Roccuzzo desde el escenario al recibir el Balón de Oro
# Luego de recibir el premio y rodeado de sus hijos, el capitán argentino no se olvidó de su esposa y tuvo una gran reacción
#
#
#
# Así fue el despegue del primer taxi volador en EE.UU. en el aeropuerto de Tampa
# Las autoridades e invitados especiales fueron testigos de la demostración de un vehículo aéreo de transporte de pasajeros que podría revolucionar la movilidad en las megaciudades
#
#
#
# Guido Kaczka notó una extraña actitud en un participante de Los 8 escalones y no dudó en exponerlo
# Tras ser consultado por un amuleto que poseía en la mano, el hombre llamado Maximiliano provocó la curiosidad del conductor, quien quedó atónito al escuchar la peculiar palabra que lanzó al aire
#
#
#
# Lloró a cámara por tener que trabajar ocho horas por jornada y sus seguidores le dieron una lección
# Cumplir el horario es una norma para la mayoría de los trabajos, sobre todo en Estados Unidos; sin embargo, eso parece no gustarle a las generaciones más recientes
#
#
#
# ¿Con qué signos del Zodíaco es más compatible alguien de Escorpio?
# Las personas nacidas bajo este signo son leales y comprometidas, por lo que buscan esos valores en sus vínculos afectivos y laborales
#
#
#
# Francisco Tinelli reveló que se sometió a una operación que le “cambió la vida”
# El hijo del conductor Marcelo Tinelli abrió su corazón para hablar del gran momento que atraviesa luego de tomar una importante decisión por su salud
#
#
#
# Qué hace a Bankso, en Bulgaria, uno de los lugares más atractivos del mundo para los nómadas digitales
# Se trata de un sitio con 10.000 residentes; en la actualidad alberga a más de 300 trabajadores remotos cada mes y la población aumenta durante la temporada de esquí
#
#
#
# Dólar hoy, dólar blue hoy: a cuánto cotiza este viernes 3 de noviembre
# La divisa estadounidense paralela se negocia a $915 para la venta; en tanto, el oficial se vende a $365,50
#
#
#
# El boliche rutero que hace 200 sándwiches en una mañana y es parada obligada desde 1981
# La familia propietaria de la estación de servicio de Piedra del Águila, donde está el local, se hizo cargo también de la cocina; los secretos del crudo y queso más codiciado
#
#
#
# El líder de Hezbollah dice que el ataque de Hamas fue “100% palestino”, pero advierte sobre una posible guerra regional: “Todas las opciones están sobre la mesa”
# Hassan Nasrallah brindó un extenso discurso por primera vez desde que estalló el conflicto y apuntó contra Estados Unidos mientras Antony Blinken está en Tel Aviv para pedir una pausa en la ofensiva israelí
#
#
#
# Se supo por qué Lionel Messi habría dejado de seguir a Lali Espósito en Instagram
# La cantante reveló, en una antigua entrevista con El Hormiguero, que algunas actitudes suyas en sus redes sociales habrían ahuyentado al futbolista
#
#
#
# Haaus. El curioso proyecto con “alma hotelera” de Palermo Soho
# Pensadas para satisfacer la demanda de alquileres temporarios, las dos torres que desarrolla CEK Group en Palermo Soho aseguran ganancias antes, durante y después de la obra
#
#
#
# Juegos Panamericanos: Robertino Pezzota, el batallador incansable del squash que sueña con tener un lugar para plasmar tantos años de trotamundos
# Referente de su deporte, el año pasado dejó el país para intentar “vivir” de lo que hace
#
#
#
# La agenda de TV del viernes: River frente a Huracán en la Copa de la Liga, el Masters 1000 de París, Fórmula 1 en Brasil y los Panamericanos
# La actividad deportiva disponible a través de las pantallas y del streaming, en una jornada de intensa actividad
#
#
#
# En el interior, el abastecimiento de combustible recién se normalizaría este fin de semana
# Si bien hubo un mayor aprovisionamiento, en la mayoría de las provincias la crisis por la falta de nafta y gasoil no está totalmente solucionada; estiman que eso sucederá recién en los próximos días
#
#
#
# El BCRA autorizó la operación y el Banco Macro cerró la compra del Itaú por US$50 millones
# El banco que dirige Jorge Brito se quedará con el 100% de la entidad; desde el 4 de noviembre, todos los productos del Itaú funcionarán bajo la marca Macro BMA; qué ocurrirá con las tarjetas, los CBU y las claves de los cajeros
#
#
#
# El Grupo Sancor Seguros nuevamente se consagró en los Premios Prestigio
# La nueva edición fue organizada por Grupo Sol Comunicaciones junto al Centro de Estudios de Opinión Pública (CEOP), que desde hace 20 años reconocen los logros de profesionales y organizaciones de la industria aseguradora argentina
#
#
#
# María y Paula Marull: la increíble historia de las gemelas que fueron modelos, trabajaron en TV y hoy forman parte de un éxito teatral
# Escribieron, dirigen y protagonizan Lo que el río hace, la obra de culto que emociona hasta las lágrimas y agota las localidades desde su estreno
#
#
#
# Mercedes y Victoria Carreras: anecdotario y detrás de escena de una familia que marcó a fuego el espectáculo argentino, en un documental imprescindible
# El film Amor y cine, que se estrena en el Festival de Cine de Mar del Plata, completa la trilogía iniciada con Merello x Carreras e Hijas de la comedia, y se centra especialmente en la obra llevada adelante por el prolífico Enrique Carreras
#
#
#
# Priscilla Presley se quebró al recordar a su hija, Lisa-Marie, habló sobre la disputa por la herencia y aseguró que hubiese preferido que Michael Jackson no se acercara a su familia
# En una reciente entrevista, la viuda de Elvis se refirió a la seguidilla de tragedias que le tocó atravesar en muy poco tiempo y que comenzó en 2020 con el suicidio de su nieto mayor, Benjamin Keough, de 27 años
#
#
#
# Seis medicamentos que no hay que mezclar con café
# Alergias, resfríos y presión arterial son algunas de las afecciones cuyos medicamentos pueden ver reducida su efectividad si se consumen junto con cafeína; las advertencias importantes a tener en cuenta
#
#
#
# Cerca de Río de Janeiro: un circuito por cuatro pueblos soñados con las playas más glamorosas de Brasil
# A pocos kilómetros de Río de Janeiro, Paraty, Búzios, Angra dos Reis y Arraial do Cabo ofrecen un  escape a la vida urbana con arenas más tranquilas, aguas cálidas y morros para caminar sin rumbo
#
#
#
# Mario Alonso Puig revela cuál es el camino infalible para la felicidad
# El médico y conferencista español dio sus máximas para alcanzar la plenitud a pesar de las inseguridades en el evento de Bienestar y Salud de LA NACION
#
#
#
# Ocho mitos sexuales que los expertos se encargan de derribar
# Resulta difícil hablar de sexo y cualquiera sea el motivo la desinformación sobre la sexualidad y el deseo es común
#
#
#
# Cuánto vale el Toyota Yaris en noviembre después del fin de Precios Justos
# El Toyota Yaris (el modelo de entrada de la marca japonesa desde la desaparición del Etios) aumentó su precio con el fin de Precios Justos y el comienzo de mes; en cuánto quedó toda la gama
#
#
#
# Cómo saber cuánta nafta consume de verdad tu auto
# El consumo de nafta es uno de los temas en agenda debido al faltante y aumento de los precios en las estaciones de servicio del país; cómo conocer el consumo real del auto (y no el que declara la fábrica)
#
#
#
# Honda lanzó la nueva generación del HR-V: cómo es y cuánto cuesta
# El SUV del segmento B llega de Brasil con cambios estéticos y el agregado de elementos de seguridad y confort; cuánto cuesta
#
#
#
# Toyota ya vende el nuevo Corolla en el país: en qué cambió
# La renovación del sedán mediano incorpora cambios estéticos en la parrilla (ahora con diseño tipo panal de abeja) y nuevo equipamiento de seguridad; los detalles
#
#
#
# Historias: las razones por las que un hombre hace dos años vive en un crucero
# Trabaja de forma remota y elabora un presupuesto anual para disfrutar de un estilo de vida que lo hace sentir de vacaciones en forma permanente: vivir en un crucero
#
#
#
# De Belgrano a Palermo: así será el nuevo polo con restaurantes y concesionarios top que abrirá sobre la avenida Libertador
# Inició la segunda etapa del mega proyecto comercial Viaviva que comenzó en el Barrio Chino y hoy busca transformar todo el viaducto que va desde Belgrano hasta Palermo
#
#
#
# Desde US$50.000 un departamento: la zona a cinco minutos de la ciudad que crece con proyectos premium y precios accesibles
# Nace un eje inmobiliario enmarcado por megaproyectos de lujo con precios accesibles para la case media y media alta
#
#
#
# Reabrió Osaka: el barrio porteño elegido por sus dueños para abrir el nuevo local del restaurante top
# Un polo gastronómico cobra fuerza  con la llegada de restaurantes de primer nivel dentro de un proyecto inmobiliario
#
#
#
# “De rodillas”: un diputado de JxC le hizo un fuerte reclamo al gobierno de Kicillof por la crisis de los tambos
# Luciano Bugallo, legislador bonaerense, pidió por una emergencia agropecuaria y medidas para la actividad que hoy tiene costos por encima del precio pagado por la leche
#
#
#
# Frontera sin control: la trama a la vista de todos para contrabandear carne a Paraguay
# En Formosa se registran maniobras para pasar medias reses enteras al país vecino de manera ilegal; los factores que impulsan, según afirman, un fenómeno en crecimiento
#
#
#
# Entre la carne y la sustentabilidad: los desafíos de la ganadería
# La idea de que dejar de consumir carne podría transformar al mundo en una sociedad vegetariana es una simplificación que no captura la complejidad de este asunto; para comprender mejor la problemática es fundamental considerar los diversos factores y consecuencias de esta posibilidad.
#
#
#
# “Chau cosecha”: a 10 días decisivos, el granizo arrasó en una región agrícola
# En San Vicente, Santa Fe, Joaquín Biancotti perdió más de 80 hectáreas del cereal que estaban casi listas para su cosecha
#
#
#
# A los 13 años falleció su papá y ese dolor le enseñó cómo afrontar los duelos: “La medicación no anestesia el proceso”
# Cuando Sol tenía 13 años su papá falleció y todo el dolor que sintió y la transformación que empezó a experimentar le es de gran ayuda a la hora de tratar estos temas con sus pacientes.
#
#
#
# Estudiar, siempre: 4 propuestas para capacitarse
# Los beneficios de Club LA NACION abarcan idiomas, cursos, talleres y carreras muy diversas.
#
#
#
# Qué hacer para tener más y mejor fruta esta temporada
# ¿Tenés un árbol frutal? Hay tareas muy sencillas que necesitamos realizar ahora para mejorar la calidad de los frutos. El especialista Juan Buela nos cuenta cuáles son y cómo hacerlas.
#
#
#
# Río de Janeiro: 15 paseos imperdibles para (re)enamorarse de la cidade maravilhosa
# Siempre hay una excusa para visitar Río de Janeiro, por primera o enésima vez. La final de la Copa Libertadores entre Boca Juniors y el Fluminense es una oportunidad para hacerse una escapada y disfrutar de una ciudad con 86 kilómetros de costa, naturaleza exuberante y una cultura vibrante.
#
#
#
# Cuándo cobro Potenciar Trabajo en noviembre y de cuánto es el monto con el bono
# Los beneficiarios de esta asistencia reciben un nuevo aumento este mes a partir de la suba del 32 por ciento del Salario Mínimo; el calendario para el cobro de esta prestación se adelantó unos días
#
#
#
# Cómo pedir el crédito de 600.000 para jubilados de Anses
# El préstamo se puede solicitar de forma online y luego hay que pedir un turno presencial; para acceder es necesario cumplir con una serie de requisitos
#
#
#
# Cómo tramitar la ciudadanía española
# El gobierno de España aprobó hace poco la “Ley del Nieto”, la cual ofrece nuevas posibilidades de acceder a la ciudadanía; ¿cuál es la documentación necesaria para gestionarla?
#
#
#
# Por qué no hay bancos este lunes 6 de noviembre
# Se celebra el Día del Trabajador Bancario; pese a que las sucursales estarán cerradas, se podrá operar desde home banking y acceder a gran parte de los servicios con normalidad

# %% [markdown]
# Genial, obtuvimos información de las principales noticias que están en la página principal de La Nación (¿se animan a agregarle la sección, el autor o autora de la nota si lo hubiere, etc.?)

# %% [markdown]
# ### Guardado de la información
#
# Si bien scrapear puede ser medio engorroso, lo bueno es que quizás solo hace falta hacerlo una única vez, es decir, una vez que obtenemos los datos que nos interesan, los guardamos y hacemos todos los análisis que nos interese.

# %%
# Creamos listas vacías para ir guardando la información
titles = []
descriptions = []
dates = []
bodies = []

# Barremos en el listado de urls
# Le ponemos un try-except para ignorar errores
for url in urls_complete:

  try:

    # Hacemos request al url actual
    response = requests.get(url)

    # Creamos la sopa
    soup = BS(response.content)

    # Identificamos el título
    title = soup.find(attrs = {"class": "com-title --font-primary --sixxl --font-extra"}).text

    # Identificamos la descripción
    description = soup.find(attrs = {"class": "com-subhead --bajada --m-xs-"}).text

    # Cuerpo de la nota
    body = soup.find("section", attrs = {"class": "cuerpo__nota"})
    paragraphs = body.findAll('p')
    # Juntamos el texto de los párrafos, separados por un salto de línea
    paragraphs_text = '\n'.join([p.text for p in paragraphs])

    # Fecha
    datetime = soup.find("meta", attrs = {"property": "article:published_time"})['content']

    # En vez de printear guardamos los datos en las listas que creamos
    titles.append(title)
    descriptions.append(description)
    dates.append(datetime)
    bodies.append(paragraphs_text)

  except:
    pass

# %% [markdown]
# Con las listas con toda la información, creamos un dataframe de pandas que para meter todo ahí y guardamos el archivo en un .csv para que quede disponible para futuros análisis.

# %%
import pandas as pd

# Creamos un dataframe vacío
df = pd.DataFrame()

df['title'] = titles
df['description'] = descriptions
df['date'] = dates
df['body'] = bodies

# Vemos las primeras líneas
df.head()
# Out:
#                                                title  \
# 0  La insólita explicación de Javier Milei por su...
# 1  “Francamente inaceptable”: Cristina Kirchner c...
# 2  Una diputada que sufrió la muerte de su bebé y...
# 3  Cuentas de los argentinos en EE. UU.: asado de...
# 4  Qué necesita Buenos Aires para convertirse en ...
#
#                                          description  \
# 0  El economista planteó que su bloque solo parti...
# 1  La vicepresidenta utilizó su cuenta de Twitter...
# 2  La legisladora Camila Crescimbeni se largó a l...
# 3  Massa estuvo ayer con el senador Bob Menendez ...
# 4  El urbanista Carlos Moreno, impulsor del conce...
#
#                        date                                               body
# 0  2022-10-26T17:14:25.489Z  Luego de las críticas de los dirigentes de Jun...
# 1  2022-10-26T14:16:00.622Z  Justo después de que terminara la entrevista q...
# 2  2022-10-26T16:53:38.098Z  Ya terminaba el debate por el Presupuesto 2023...
# 3  2022-10-26T15:59:00.204Z  Sergio Massa se acostó esta mañana, luego de l...
# 4  2022-10-26T14:20:02.724Z  Hay un concepto que los urbanistas del gobiern...

# %%
# Guardamos el archivo que podemos descargar
df.to_csv('InfoLaNacion.csv', index = False)

# %% [markdown]
# ### Tarea para el hogar
#
# - Encuentre una paǵina de interés y trate de extraer información que le interese (no todas son fáciles de hacer, no se frustre si falla...). Ejemplo, pueden ser páginas con letras de canciones, recetas de cocina, artículos en blogs, etc.
# - Si tiene un conjunto de páginas, guarde la información relevante en dataframe de pandas para poder analizarla. Por ejemplo, puede hacer descomposición en tópicos o análisis de sentimiento de textos descargados.
